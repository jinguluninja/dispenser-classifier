# %%
import os
import keras
import numpy as np
np.random.seed(135109)
# Out:
# Using TensorFlow backend.

# %%
sensor = '24'

# %%
def dataset():
    X = []
    y = []
    data_dir_0 = sorted(os.listdir(os.path.join('pac_data', sensor, '0')))   
    i = 0
    for f in data_dir_0:
        if i % 100 == 0: print(i)
        i += 1
        X.append(np.load(os.path.join('pac_data', sensor, '0', f))['x'])
        y.append(0)
    X = np.asarray(X, dtype=np.float16)
    y = np.asarray(y, dtype=int)
    indices = np.arange(y.shape[0])
    np.random.shuffle(indices)
    X_train = X[indices[:int(0.8*len(indices))]]
    y_train = y[indices[:int(0.8*len(indices))]]
    X_val = X[indices[int(0.8*len(indices)):]]
    y_val = y[indices[int(0.8*len(indices)):]]
    labels_present = os.listdir(os.path.join('pac_data', sensor))
    if '1' in labels_present:
        X = []
        y = []
        data_dir_1 = sorted(os.listdir(os.path.join('pac_data', sensor, '1')))
        i = 0
        for f in data_dir_1:
            if i % 100 == 0: print(i)
            i += 1
            X.append(np.load(os.path.join('pac_data', sensor, '1', f))['x'])
            y.append(1)        
        X = np.asarray(X, dtype=np.float16)
        y = np.asarray(y, dtype=int)
        indices = np.arange(y.shape[0])
        np.random.shuffle(indices)
        X_train = np.concatenate([X_train, X[indices[:int(0.8*len(indices))]]])
        y_train = np.concatenate([y_train, y[indices[:int(0.8*len(indices))]]])
        X_val = np.concatenate([X_val, X[indices[int(0.8*len(indices)):]]])
        y_val = np.concatenate([y_val, y[indices[int(0.8*len(indices)):]]])
    X_train = np.expand_dims(np.asarray(X_train, dtype=np.float16), axis=3)
    y_train = np.asarray(y_train, dtype=int)
    X_val = np.expand_dims(np.asarray(X_val, dtype=np.float16), axis=3)
    y_val = np.asarray(y_val, dtype=int)
    X_train /= 5.
    X_val /= 5.
    mean_arr = np.mean(X_train, axis = 0)
    np.save(os.path.join('pac_data', sensor, 'mean.npy'), mean_arr)
    X_train -= mean_arr 
    X_val -= mean_arr  
    return X_train, y_train, X_val, y_val

# %%
X_train, y_train, X_val, y_val = dataset()
# Out:
# 0

# %%
print(X_train.shape, y_train.shape, X_val.shape, y_val.shape)
# Out:
# (28, 240, 320, 1) (28,) (7, 240, 320, 1) (7,)

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/gpu:0']

# %%
from keras.models import Sequential
from keras.layers import TimeDistributed, GlobalAveragePooling2D, Activation, Dense, Input
from keras.layers import BatchNormalization, Conv2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D
from keras.layers import GlobalMaxPooling2D
from keras.layers.recurrent import LSTM
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras.layers import Dropout, Flatten
from keras.layers import concatenate
from keras import regularizers
from keras import initializers
from keras import constraints
from keras.models import Model
from keras import backend as K
from keras.utils.layer_utils import convert_all_kernels_in_model
from keras.utils.data_utils import get_file
from keras.utils import conv_utils
from keras.engine.topology import get_source_inputs
from keras.engine import InputSpec
from keras.applications.xception import Xception
from keras import metrics

# %%
#linear
def linear(dropout):
    inputs = Input(shape=(240, 320, 1))
    x = Flatten()(inputs)
    x = Dropout(dropout)(x)
    x = Dense(2, activation='softmax')(x)
    model = Model(inputs, x, name='linear')
    return model

# %%
from keras import layers
from keras.layers import Activation
from keras.layers import SeparableConv2D

def xception(dropout):
    inputs = Input(shape=(240, 320, 1))    

    x = Conv2D(32, (3, 3), padding='same', strides=(2, 2), use_bias=False, name='block1_conv1')(inputs)
    x = BatchNormalization(name='block1_conv1_bn')(x)
    x = Activation('relu', name='block1_conv1_act')(x)
    x = Conv2D(64, (3, 3), padding='same', use_bias=False, name='block1_conv2')(x)
    x = BatchNormalization(name='block1_conv2_bn')(x)
    x = Activation('relu', name='block1_conv2_act')(x)

    residual = Conv2D(128, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, name='block2_sepconv1')(x)
    x = BatchNormalization(name='block2_sepconv1_bn')(x)
    x = Activation('relu', name='block2_sepconv2_act')(x)
    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, name='block2_sepconv2')(x)
    x = BatchNormalization(name='block2_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block2_pool')(x)
    x = layers.add([x, residual])

    residual = Conv2D(256, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block3_sepconv1_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, name='block3_sepconv1')(x)
    x = BatchNormalization(name='block3_sepconv1_bn')(x)
    x = Activation('relu', name='block3_sepconv2_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, name='block3_sepconv2')(x)
    x = BatchNormalization(name='block3_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block3_pool')(x)
    x = layers.add([x, residual])

    residual = Conv2D(728, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block4_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name='block4_sepconv1')(x)
    x = BatchNormalization(name='block4_sepconv1_bn')(x)
    x = Activation('relu', name='block4_sepconv2_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name='block4_sepconv2')(x)
    x = BatchNormalization(name='block4_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block4_pool')(x)
    x = layers.add([x, residual])

    for i in range(8):
        residual = x
        prefix = 'block' + str(i + 5)

        x = Activation('relu', name=prefix + '_sepconv1_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name=prefix + '_sepconv1')(x)
        x = BatchNormalization(name=prefix + '_sepconv1_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv2_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name=prefix + '_sepconv2')(x)
        x = BatchNormalization(name=prefix + '_sepconv2_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv3_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name=prefix + '_sepconv3')(x)
        x = BatchNormalization(name=prefix + '_sepconv3_bn')(x)

        x = layers.add([x, residual])

    residual = Conv2D(1024, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block13_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name='block13_sepconv1')(x)
    x = BatchNormalization(name='block13_sepconv1_bn')(x)
    x = Activation('relu', name='block13_sepconv2_act')(x)
    x = SeparableConv2D(1024, (3, 3), padding='same', use_bias=False, name='block13_sepconv2')(x)
    x = BatchNormalization(name='block13_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block13_pool')(x)
    x = layers.add([x, residual])

    x = SeparableConv2D(1536, (3, 3), padding='same', use_bias=False, name='block14_sepconv1')(x)
    x = BatchNormalization(name='block14_sepconv1_bn')(x)
    x = Activation('relu', name='block14_sepconv1_act')(x)

    x = SeparableConv2D(2048, (3, 3), padding='same', use_bias=False, name='block14_sepconv2')(x)
    x = BatchNormalization(name='block14_sepconv2_bn')(x)
    x = Activation('relu', name='block14_sepconv2_act')(x)

    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dropout(dropout)(x)
    x = Dense(2, activation='softmax', name='predictions')(x)
    model = Model(inputs, x, name='xception')
    return model


'''
def xception(dropout):
    base_model = Xception(include_top=False, input_shape = (240, 320, 1), pooling='avg')
    x = base_model.output
    x = Flatten()(x)
    x = Dropout(dropout)(x) # drop prob
    predictions = Dense(2, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions, name='linear')
    return model
'''
# Out:
# "\ndef xception(dropout):\n    base_model = Xception(include_top=False, input_shape = (240, 320, 1), pooling='avg')\n    x = base_model.output\n    x = Flatten()(x)\n    x = Dropout(dropout)(x) # drop prob\n    predictions = Dense(2, activation='softmax')(x)\n    model = Model(inputs=base_model.input, outputs=predictions, name='linear')\n    return model\n"

# %%
def vanillacnn(dropout):
    inputs = Input(shape=(240, 320, 1)) 
    x = Conv2D(32, (3, 3), strides=(2, 2), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = Dropout(dropout)(x)
    
    x = Conv2D(64, (3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = Dropout(dropout)(x)
    
    x = Conv2D(128, (3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = Dropout(dropout)(x)
    
    x = Conv2D(256, (3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    
    x = Flatten()(x)
    x = Dropout(dropout)(x)
    x = Dense(2, activation='softmax', name='predictions')(x)
    model = Model(inputs, x, name='xception')
    return model

# %%
model_name = 'model' + sensor + '.h5'
model = vanillacnn(0.5)

adam = keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=[metrics.sparse_categorical_accuracy])


checkpoint = ModelCheckpoint(model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
stop = EarlyStopping(patience=20, verbose=1)

callbacks_list = [checkpoint, stop]

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 240, 320, 1)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 120, 160, 32)      320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 120, 160, 32)      128
# _________________________________________________________________
# activation_1 (Activation)    (None, 120, 160, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 60, 80, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60, 80, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 40, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 30, 40, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 40, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 15, 20, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 15, 20, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 10, 128)        73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 10, 128)        512
# _________________________________________________________________
# activation_3 (Activation)    (None, 8, 10, 128)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 5, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 5, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 3, 256)         295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2, 3, 256)         1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 2, 3, 256)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 2, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# predictions (Dense)          (None, 2)                 1026
# =================================================================
# Total params: 390,786
# Trainable params: 389,826
# Non-trainable params: 960
# _________________________________________________________________

# %%
model.fit(x=X_train, 
          y=y_train, 
          batch_size=32, 
          epochs=100, 
          verbose=1, 
          callbacks=callbacks_list, 
          validation_data=(X_val, y_val), 
          shuffle=True)
# Out:
# Train on 28 samples, validate on 7 samples
# Epoch 1/100
# Epoch 00000: val_loss improved from inf to 0.62601, saving model to model24.h5
# 28/28 [==============================] - 1s - loss: 0.8031 - sparse_categorical_accuracy: 0.6429 - val_loss: 0.6260 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/100
# Epoch 00001: val_loss improved from 0.62601 to 0.56778, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 0.0431 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5678 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/100
# Epoch 00002: val_loss improved from 0.56778 to 0.52239, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 0.0093 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5224 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/100
# Epoch 00003: val_loss improved from 0.52239 to 0.48770, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 2.5922e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4877 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/100
# Epoch 00004: val_loss improved from 0.48770 to 0.46223, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 3.5878e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4622 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/100
# Epoch 00005: val_loss improved from 0.46223 to 0.44202, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.4364e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4420 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/100
# Epoch 00006: val_loss improved from 0.44202 to 0.42756, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 3.5081e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4276 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/100
# Epoch 00007: val_loss improved from 0.42756 to 0.41573, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 3.6571e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4157 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/100
# Epoch 00008: val_loss improved from 0.41573 to 0.40490, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 8.5149e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4049 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/100
# Epoch 00009: val_loss improved from 0.40490 to 0.39551, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 6.0877e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3955 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/100
# Epoch 00010: val_loss improved from 0.39551 to 0.38529, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 3.7466e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3853 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/100
# Epoch 00011: val_loss improved from 0.38529 to 0.37465, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.6178e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3746 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/100
# Epoch 00012: val_loss improved from 0.37465 to 0.36305, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 4.8535e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3630 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/100
# Epoch 00013: val_loss improved from 0.36305 to 0.35034, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 3.7891e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3503 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/100
# Epoch 00014: val_loss improved from 0.35034 to 0.33602, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.4475e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3360 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/100
# Epoch 00015: val_loss improved from 0.33602 to 0.32132, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.7030e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3213 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/100
# Epoch 00016: val_loss improved from 0.32132 to 0.30635, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.3198e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3063 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/100
# Epoch 00017: val_loss improved from 0.30635 to 0.29145, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 2.3416e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2914 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/100
# Epoch 00018: val_loss improved from 0.29145 to 0.27717, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.6178e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2772 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/100
# Epoch 00019: val_loss improved from 0.27717 to 0.26331, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 2.3842e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2633 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/100
# Epoch 00020: val_loss improved from 0.26331 to 0.24993, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2499 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/100
# Epoch 00021: val_loss improved from 0.24993 to 0.23721, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 5.6624e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2372 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/100
# Epoch 00022: val_loss improved from 0.23721 to 0.22549, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.6604e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2255 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/100
# Epoch 00023: val_loss improved from 0.22549 to 0.21451, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2145 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/100
# Epoch 00024: val_loss improved from 0.21451 to 0.20396, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2040 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/100
# Epoch 00025: val_loss improved from 0.20396 to 0.19418, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.3624e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1942 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/100
# Epoch 00026: val_loss improved from 0.19418 to 0.18519, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.2347e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1852 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/100
# Epoch 00027: val_loss improved from 0.18519 to 0.17629, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.2347e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1763 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/100
# Epoch 00028: val_loss improved from 0.17629 to 0.16813, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1681 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/100
# Epoch 00029: val_loss improved from 0.16813 to 0.16063, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.2347e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1606 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/100
# Epoch 00030: val_loss improved from 0.16063 to 0.15367, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 2.1287e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1537 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/100
# Epoch 00031: val_loss improved from 0.15367 to 0.14728, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.3198e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1473 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/100
# Epoch 00032: val_loss improved from 0.14728 to 0.14127, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1413 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/100
# Epoch 00033: val_loss improved from 0.14127 to 0.13528, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.9584e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1353 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/100
# Epoch 00034: val_loss improved from 0.13528 to 0.12973, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.5327e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1297 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/100
# Epoch 00035: val_loss improved from 0.12973 to 0.12458, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.2772e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1246 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/100
# Epoch 00036: val_loss improved from 0.12458 to 0.11998, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1200 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/100
# Epoch 00037: val_loss improved from 0.11998 to 0.11542, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.3198e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1154 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/100
# Epoch 00038: val_loss improved from 0.11542 to 0.11135, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.8307e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1114 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/100
# Epoch 00039: val_loss improved from 0.11135 to 0.10740, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.4901e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1074 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/100
# Epoch 00040: val_loss improved from 0.10740 to 0.10350, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.3198e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1035 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/100
# Epoch 00041: val_loss improved from 0.10350 to 0.09995, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0999 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/100
# Epoch 00042: val_loss improved from 0.09995 to 0.09670, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.2347e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0967 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/100
# Epoch 00043: val_loss improved from 0.09670 to 0.09354, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 2.8099e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0935 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/100
# Epoch 00044: val_loss improved from 0.09354 to 0.09065, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.3198e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0906 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/100
# Epoch 00045: val_loss improved from 0.09065 to 0.08765, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.5327e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0876 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/100
# Epoch 00046: val_loss improved from 0.08765 to 0.08496, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.3198e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0850 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/100
# Epoch 00047: val_loss improved from 0.08496 to 0.08228, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.3198e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0823 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/100
# Epoch 00048: val_loss improved from 0.08228 to 0.07991, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.5327e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0799 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/100
# Epoch 00049: val_loss improved from 0.07991 to 0.07757, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.3198e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0776 - val_sparse_categorical_accuracy: 1.0000
# Epoch 51/100
# Epoch 00050: val_loss improved from 0.07757 to 0.07545, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.5753e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0755 - val_sparse_categorical_accuracy: 1.0000
# Epoch 52/100
# Epoch 00051: val_loss improved from 0.07545 to 0.07336, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.6178e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0734 - val_sparse_categorical_accuracy: 1.0000
# Epoch 53/100
# Epoch 00052: val_loss improved from 0.07336 to 0.07133, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.2772e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0713 - val_sparse_categorical_accuracy: 1.0000
# Epoch 54/100
# Epoch 00053: val_loss improved from 0.07133 to 0.06939, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.4050e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0694 - val_sparse_categorical_accuracy: 1.0000
# Epoch 55/100
# Epoch 00054: val_loss improved from 0.06939 to 0.06757, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.2772e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0676 - val_sparse_categorical_accuracy: 1.0000
# Epoch 56/100
# Epoch 00055: val_loss improved from 0.06757 to 0.06590, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.4475e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0659 - val_sparse_categorical_accuracy: 1.0000
# Epoch 57/100
# Epoch 00056: val_loss improved from 0.06590 to 0.06426, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.7030e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0643 - val_sparse_categorical_accuracy: 1.0000
# Epoch 58/100
# Epoch 00057: val_loss improved from 0.06426 to 0.06266, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0627 - val_sparse_categorical_accuracy: 1.0000
# Epoch 59/100
# Epoch 00058: val_loss improved from 0.06266 to 0.06113, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.3198e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0611 - val_sparse_categorical_accuracy: 1.0000
# Epoch 60/100
# Epoch 00059: val_loss improved from 0.06113 to 0.05965, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0596 - val_sparse_categorical_accuracy: 1.0000
# Epoch 61/100
# Epoch 00060: val_loss improved from 0.05965 to 0.05817, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.7456e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0582 - val_sparse_categorical_accuracy: 1.0000
# Epoch 62/100
# Epoch 00061: val_loss improved from 0.05817 to 0.05676, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0568 - val_sparse_categorical_accuracy: 1.0000
# Epoch 63/100
# Epoch 00062: val_loss improved from 0.05676 to 0.05550, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0555 - val_sparse_categorical_accuracy: 1.0000
# Epoch 64/100
# Epoch 00063: val_loss improved from 0.05550 to 0.05423, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.3198e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0542 - val_sparse_categorical_accuracy: 1.0000
# Epoch 65/100
# Epoch 00064: val_loss improved from 0.05423 to 0.05298, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0530 - val_sparse_categorical_accuracy: 1.0000
# Epoch 66/100
# Epoch 00065: val_loss improved from 0.05298 to 0.05185, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.3624e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0518 - val_sparse_categorical_accuracy: 1.0000
# Epoch 67/100
# Epoch 00066: val_loss improved from 0.05185 to 0.05072, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.2347e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0507 - val_sparse_categorical_accuracy: 1.0000
# Epoch 68/100
# Epoch 00067: val_loss improved from 0.05072 to 0.04965, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0497 - val_sparse_categorical_accuracy: 1.0000
# Epoch 69/100
# Epoch 00068: val_loss improved from 0.04965 to 0.04862, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.6604e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0486 - val_sparse_categorical_accuracy: 1.0000
# Epoch 70/100
# Epoch 00069: val_loss improved from 0.04862 to 0.04768, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0477 - val_sparse_categorical_accuracy: 1.0000
# Epoch 71/100
# Epoch 00070: val_loss improved from 0.04768 to 0.04671, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 2.2139e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0467 - val_sparse_categorical_accuracy: 1.0000
# Epoch 72/100
# Epoch 00071: val_loss improved from 0.04671 to 0.04566, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.2772e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0457 - val_sparse_categorical_accuracy: 1.0000
# Epoch 73/100
# Epoch 00072: val_loss improved from 0.04566 to 0.04474, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.3624e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0447 - val_sparse_categorical_accuracy: 1.0000
# Epoch 74/100
# Epoch 00073: val_loss improved from 0.04474 to 0.04390, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.3624e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0439 - val_sparse_categorical_accuracy: 1.0000
# Epoch 75/100
# Epoch 00074: val_loss improved from 0.04390 to 0.04313, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.2347e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0431 - val_sparse_categorical_accuracy: 1.0000
# Epoch 76/100
# Epoch 00075: val_loss improved from 0.04313 to 0.04228, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0423 - val_sparse_categorical_accuracy: 1.0000
# Epoch 77/100
# Epoch 00076: val_loss improved from 0.04228 to 0.04146, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.4050e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0415 - val_sparse_categorical_accuracy: 1.0000
# Epoch 78/100
# Epoch 00077: val_loss improved from 0.04146 to 0.04076, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0408 - val_sparse_categorical_accuracy: 1.0000
# Epoch 79/100
# Epoch 00078: val_loss improved from 0.04076 to 0.04000, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.2347e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0400 - val_sparse_categorical_accuracy: 1.0000
# Epoch 80/100
# Epoch 00079: val_loss improved from 0.04000 to 0.03930, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 3.1931e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0393 - val_sparse_categorical_accuracy: 1.0000
# Epoch 81/100
# Epoch 00080: val_loss improved from 0.03930 to 0.03866, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0387 - val_sparse_categorical_accuracy: 1.0000
# Epoch 82/100
# Epoch 00081: val_loss improved from 0.03866 to 0.03800, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.5327e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0380 - val_sparse_categorical_accuracy: 1.0000
# Epoch 83/100
# Epoch 00082: val_loss improved from 0.03800 to 0.03743, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0374 - val_sparse_categorical_accuracy: 1.0000
# Epoch 84/100
# Epoch 00083: val_loss improved from 0.03743 to 0.03681, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.3624e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0368 - val_sparse_categorical_accuracy: 1.0000
# Epoch 85/100
# Epoch 00084: val_loss improved from 0.03681 to 0.03620, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 2.2565e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0362 - val_sparse_categorical_accuracy: 1.0000
# Epoch 86/100
# Epoch 00085: val_loss improved from 0.03620 to 0.03570, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0357 - val_sparse_categorical_accuracy: 1.0000
# Epoch 87/100
# Epoch 00086: val_loss improved from 0.03570 to 0.03513, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.4475e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0351 - val_sparse_categorical_accuracy: 1.0000
# Epoch 88/100
# Epoch 00087: val_loss improved from 0.03513 to 0.03456, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 3.3208e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0346 - val_sparse_categorical_accuracy: 1.0000
# Epoch 89/100
# Epoch 00088: val_loss improved from 0.03456 to 0.03403, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0340 - val_sparse_categorical_accuracy: 1.0000
# Epoch 90/100
# Epoch 00089: val_loss improved from 0.03403 to 0.03353, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.2347e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0335 - val_sparse_categorical_accuracy: 1.0000
# Epoch 91/100
# Epoch 00090: val_loss improved from 0.03353 to 0.03306, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.2772e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0331 - val_sparse_categorical_accuracy: 1.0000
# Epoch 92/100
# Epoch 00091: val_loss improved from 0.03306 to 0.03255, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.2347e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0326 - val_sparse_categorical_accuracy: 1.0000
# Epoch 93/100
# Epoch 00092: val_loss improved from 0.03255 to 0.03205, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0321 - val_sparse_categorical_accuracy: 1.0000
# Epoch 94/100
# Epoch 00093: val_loss improved from 0.03205 to 0.03167, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.3198e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0317 - val_sparse_categorical_accuracy: 1.0000
# Epoch 95/100
# Epoch 00094: val_loss improved from 0.03167 to 0.03120, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.5327e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0312 - val_sparse_categorical_accuracy: 1.0000
# Epoch 96/100
# Epoch 00095: val_loss improved from 0.03120 to 0.03071, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.6604e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0307 - val_sparse_categorical_accuracy: 1.0000
# Epoch 97/100
# Epoch 00096: val_loss improved from 0.03071 to 0.03030, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0303 - val_sparse_categorical_accuracy: 1.0000
# Epoch 98/100
# Epoch 00097: val_loss improved from 0.03030 to 0.02990, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.4475e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0299 - val_sparse_categorical_accuracy: 1.0000
# Epoch 99/100
# Epoch 00098: val_loss improved from 0.02990 to 0.02951, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.2772e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0295 - val_sparse_categorical_accuracy: 1.0000
# Epoch 100/100
# Epoch 00099: val_loss improved from 0.02951 to 0.02915, saving model to model24.h5
# 28/28 [==============================] - 0s - loss: 1.3198e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0291 - val_sparse_categorical_accuracy: 1.0000

# %%
from keras.models import load_model
trained_model = load_model(model_name)
print(trained_model.metrics_names)
trained_model.evaluate(x=X_train, y=y_train)
# Out:
# ['loss', 'sparse_categorical_accuracy']
# 28/28 [==============================] - 0s
# [0.029273323714733124, 1.0]

# %%
trained_model.evaluate(x=X_val, y=y_val)
# Out:
# 7/7 [==============================] - 0s
# [0.029148517176508904, 1.0]
