# %%
import os
import keras
import numpy as np
np.random.seed(135109)
# Out:
# Using TensorFlow backend.

# %%
sensor = '10'

# %%
def dataset():
    X = []
    y = []
    data_dir_0 = sorted(os.listdir(os.path.join('pac_data', sensor, '0')))   
    i = 0
    for f in data_dir_0:
        if i % 100 == 0: print(i)
        i += 1
        X.append(np.load(os.path.join('pac_data', sensor, '0', f))['x'])
        y.append(0)
    X = np.asarray(X, dtype=np.float16)
    y = np.asarray(y, dtype=int)
    indices = np.arange(y.shape[0])
    np.random.shuffle(indices)
    X_train = X[indices[:int(0.8*len(indices))]]
    y_train = y[indices[:int(0.8*len(indices))]]
    X_val = X[indices[int(0.8*len(indices)):]]
    y_val = y[indices[int(0.8*len(indices)):]]
    labels_present = os.listdir(os.path.join('pac_data', sensor))
    if '1' in labels_present:
        X = []
        y = []
        data_dir_1 = sorted(os.listdir(os.path.join('pac_data', sensor, '1')))
        i = 0
        for f in data_dir_1:
            if i % 100 == 0: print(i)
            i += 1
            X.append(np.load(os.path.join('pac_data', sensor, '1', f))['x'])
            y.append(1)        
        X = np.asarray(X, dtype=np.float16)
        y = np.asarray(y, dtype=int)
        indices = np.arange(y.shape[0])
        np.random.shuffle(indices)
        X_train = np.concatenate([X_train, X[indices[:int(0.8*len(indices))]]])
        y_train = np.concatenate([y_train, y[indices[:int(0.8*len(indices))]]])
        X_val = np.concatenate([X_val, X[indices[int(0.8*len(indices)):]]])
        y_val = np.concatenate([y_val, y[indices[int(0.8*len(indices)):]]])
    X_train = np.expand_dims(np.asarray(X_train, dtype=np.float16), axis=3)
    y_train = np.asarray(y_train, dtype=int)
    X_val = np.expand_dims(np.asarray(X_val, dtype=np.float16), axis=3)
    y_val = np.asarray(y_val, dtype=int)
    X_train /= 5.
    X_val /= 5.
    mean_arr = np.mean(X_train, axis = 0)
    np.save(os.path.join('pac_data', sensor, 'mean.npy'), mean_arr)
    X_train -= mean_arr 
    X_val -= mean_arr  
    return X_train, y_train, X_val, y_val

# %%
X_train, y_train, X_val, y_val = dataset()
# Out:
# 0

# %%
print(X_train.shape, y_train.shape, X_val.shape, y_val.shape)
# Out:
# (32, 240, 320, 1) (32,) (8, 240, 320, 1) (8,)

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/gpu:0']

# %%
from keras.models import Sequential
from keras.layers import TimeDistributed, GlobalAveragePooling2D, Activation, Dense, Input
from keras.layers import BatchNormalization, Conv2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D
from keras.layers import GlobalMaxPooling2D
from keras.layers.recurrent import LSTM
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras.layers import Dropout, Flatten
from keras.layers import concatenate
from keras import regularizers
from keras import initializers
from keras import constraints
from keras.models import Model
from keras import backend as K
from keras.utils.layer_utils import convert_all_kernels_in_model
from keras.utils.data_utils import get_file
from keras.utils import conv_utils
from keras.engine.topology import get_source_inputs
from keras.engine import InputSpec
from keras.applications.xception import Xception
from keras import metrics

# %%
#linear
def linear(dropout):
    inputs = Input(shape=(240, 320, 1))
    x = Flatten()(inputs)
    x = Dropout(dropout)(x)
    x = Dense(2, activation='softmax')(x)
    model = Model(inputs, x, name='linear')
    return model

# %%
from keras import layers
from keras.layers import Activation
from keras.layers import SeparableConv2D

def xception(dropout):
    inputs = Input(shape=(240, 320, 1))    

    x = Conv2D(32, (3, 3), padding='same', strides=(2, 2), use_bias=False, name='block1_conv1')(inputs)
    x = BatchNormalization(name='block1_conv1_bn')(x)
    x = Activation('relu', name='block1_conv1_act')(x)
    x = Conv2D(64, (3, 3), padding='same', use_bias=False, name='block1_conv2')(x)
    x = BatchNormalization(name='block1_conv2_bn')(x)
    x = Activation('relu', name='block1_conv2_act')(x)

    residual = Conv2D(128, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, name='block2_sepconv1')(x)
    x = BatchNormalization(name='block2_sepconv1_bn')(x)
    x = Activation('relu', name='block2_sepconv2_act')(x)
    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, name='block2_sepconv2')(x)
    x = BatchNormalization(name='block2_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block2_pool')(x)
    x = layers.add([x, residual])

    residual = Conv2D(256, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block3_sepconv1_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, name='block3_sepconv1')(x)
    x = BatchNormalization(name='block3_sepconv1_bn')(x)
    x = Activation('relu', name='block3_sepconv2_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, name='block3_sepconv2')(x)
    x = BatchNormalization(name='block3_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block3_pool')(x)
    x = layers.add([x, residual])

    residual = Conv2D(728, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block4_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name='block4_sepconv1')(x)
    x = BatchNormalization(name='block4_sepconv1_bn')(x)
    x = Activation('relu', name='block4_sepconv2_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name='block4_sepconv2')(x)
    x = BatchNormalization(name='block4_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block4_pool')(x)
    x = layers.add([x, residual])

    for i in range(8):
        residual = x
        prefix = 'block' + str(i + 5)

        x = Activation('relu', name=prefix + '_sepconv1_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name=prefix + '_sepconv1')(x)
        x = BatchNormalization(name=prefix + '_sepconv1_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv2_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name=prefix + '_sepconv2')(x)
        x = BatchNormalization(name=prefix + '_sepconv2_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv3_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name=prefix + '_sepconv3')(x)
        x = BatchNormalization(name=prefix + '_sepconv3_bn')(x)

        x = layers.add([x, residual])

    residual = Conv2D(1024, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block13_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name='block13_sepconv1')(x)
    x = BatchNormalization(name='block13_sepconv1_bn')(x)
    x = Activation('relu', name='block13_sepconv2_act')(x)
    x = SeparableConv2D(1024, (3, 3), padding='same', use_bias=False, name='block13_sepconv2')(x)
    x = BatchNormalization(name='block13_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block13_pool')(x)
    x = layers.add([x, residual])

    x = SeparableConv2D(1536, (3, 3), padding='same', use_bias=False, name='block14_sepconv1')(x)
    x = BatchNormalization(name='block14_sepconv1_bn')(x)
    x = Activation('relu', name='block14_sepconv1_act')(x)

    x = SeparableConv2D(2048, (3, 3), padding='same', use_bias=False, name='block14_sepconv2')(x)
    x = BatchNormalization(name='block14_sepconv2_bn')(x)
    x = Activation('relu', name='block14_sepconv2_act')(x)

    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dropout(dropout)(x)
    x = Dense(2, activation='softmax', name='predictions')(x)
    model = Model(inputs, x, name='xception')
    return model


'''
def xception(dropout):
    base_model = Xception(include_top=False, input_shape = (240, 320, 1), pooling='avg')
    x = base_model.output
    x = Flatten()(x)
    x = Dropout(dropout)(x) # drop prob
    predictions = Dense(2, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions, name='linear')
    return model
'''
# Out:
# "\ndef xception(dropout):\n    base_model = Xception(include_top=False, input_shape = (240, 320, 1), pooling='avg')\n    x = base_model.output\n    x = Flatten()(x)\n    x = Dropout(dropout)(x) # drop prob\n    predictions = Dense(2, activation='softmax')(x)\n    model = Model(inputs=base_model.input, outputs=predictions, name='linear')\n    return model\n"

# %%
def vanillacnn(dropout):
    inputs = Input(shape=(240, 320, 1)) 
    x = Conv2D(32, (3, 3), strides=(2, 2), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = Dropout(dropout)(x)
    
    x = Conv2D(64, (3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = Dropout(dropout)(x)
    
    x = Conv2D(128, (3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = Dropout(dropout)(x)
    
    x = Conv2D(256, (3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    
    x = Flatten()(x)
    x = Dropout(dropout)(x)
    x = Dense(2, activation='softmax', name='predictions')(x)
    model = Model(inputs, x, name='xception')
    return model

# %%
model_name = 'model' + sensor + '.h5'
model = vanillacnn(0.5)

adam = keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=[metrics.sparse_categorical_accuracy])


checkpoint = ModelCheckpoint(model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
stop = EarlyStopping(patience=20, verbose=1)

callbacks_list = [checkpoint, stop]

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 240, 320, 1)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 120, 160, 32)      320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 120, 160, 32)      128
# _________________________________________________________________
# activation_1 (Activation)    (None, 120, 160, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 60, 80, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60, 80, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 40, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 30, 40, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 40, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 15, 20, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 15, 20, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 10, 128)        73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 10, 128)        512
# _________________________________________________________________
# activation_3 (Activation)    (None, 8, 10, 128)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 5, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 5, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 3, 256)         295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2, 3, 256)         1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 2, 3, 256)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 2, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# predictions (Dense)          (None, 2)                 1026
# =================================================================
# Total params: 390,786
# Trainable params: 389,826
# Non-trainable params: 960
# _________________________________________________________________

# %%
model.fit(x=X_train, 
          y=y_train, 
          batch_size=32, 
          epochs=1000, 
          verbose=1, 
          callbacks=callbacks_list, 
          validation_data=(X_val, y_val), 
          shuffle=True)
# Out:
# Train on 32 samples, validate on 8 samples
# Epoch 1/1000
# Epoch 00000: val_loss improved from inf to 0.64642, saving model to model10.h5
# 32/32 [==============================] - 1s - loss: 0.3145 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.6464 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/1000
# Epoch 00001: val_loss improved from 0.64642 to 0.60900, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 0.0119 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6090 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/1000
# Epoch 00002: val_loss improved from 0.60900 to 0.56726, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 9.5707e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5673 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/1000
# Epoch 00003: val_loss improved from 0.56726 to 0.52622, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 5.7406e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5262 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/1000
# Epoch 00004: val_loss improved from 0.52622 to 0.49075, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 5.4412e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4908 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/1000
# Epoch 00005: val_loss improved from 0.49075 to 0.45903, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3372e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4590 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/1000
# Epoch 00006: val_loss improved from 0.45903 to 0.42794, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.7881e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4279 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/1000
# Epoch 00007: val_loss improved from 0.42794 to 0.39770, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 4.1723e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3977 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/1000
# Epoch 00008: val_loss improved from 0.39770 to 0.36841, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3336e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3684 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/1000
# Epoch 00009: val_loss improved from 0.36841 to 0.33881, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.3543e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3388 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/1000
# Epoch 00010: val_loss improved from 0.33881 to 0.31031, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 3.7625e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3103 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/1000
# Epoch 00011: val_loss improved from 0.31031 to 0.28186, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 4.9174e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2819 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/1000
# Epoch 00012: val_loss improved from 0.28186 to 0.25498, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 9.9837e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2550 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/1000
# Epoch 00013: val_loss improved from 0.25498 to 0.22996, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 3.1440e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2300 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/1000
# Epoch 00014: val_loss improved from 0.22996 to 0.20671, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.5332e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2067 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/1000
# Epoch 00015: val_loss improved from 0.20671 to 0.18571, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 3.1665e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1857 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/1000
# Epoch 00016: val_loss improved from 0.18571 to 0.16610, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3039e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1661 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/1000
# Epoch 00017: val_loss improved from 0.16610 to 0.14888, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.9430e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1489 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/1000
# Epoch 00018: val_loss improved from 0.14888 to 0.13299, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 5.3271e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1330 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/1000
# Epoch 00019: val_loss improved from 0.13299 to 0.11921, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.4156e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1192 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/1000
# Epoch 00020: val_loss improved from 0.11921 to 0.10646, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1065 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/1000
# Epoch 00021: val_loss improved from 0.10646 to 0.09539, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.4156e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0954 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/1000
# Epoch 00022: val_loss improved from 0.09539 to 0.08564, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.7136e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0856 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/1000
# Epoch 00023: val_loss improved from 0.08564 to 0.07689, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.9744e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0769 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/1000
# Epoch 00024: val_loss improved from 0.07689 to 0.06913, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.5274e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0691 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/1000
# Epoch 00025: val_loss improved from 0.06913 to 0.06219, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3784e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0622 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/1000
# Epoch 00026: val_loss improved from 0.06219 to 0.05605, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.1607e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0561 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/1000
# Epoch 00027: val_loss improved from 0.05605 to 0.05066, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3411e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0507 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/1000
# Epoch 00028: val_loss improved from 0.05066 to 0.04570, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3411e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0457 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/1000
# Epoch 00029: val_loss improved from 0.04570 to 0.04138, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3784e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0414 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/1000
# Epoch 00030: val_loss improved from 0.04138 to 0.03757, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3411e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0376 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/1000
# Epoch 00031: val_loss improved from 0.03757 to 0.03401, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3784e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0340 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/1000
# Epoch 00032: val_loss improved from 0.03401 to 0.03094, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0309 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/1000
# Epoch 00033: val_loss improved from 0.03094 to 0.02815, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.6764e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0282 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/1000
# Epoch 00034: val_loss improved from 0.02815 to 0.02567, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3784e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0257 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/1000
# Epoch 00035: val_loss improved from 0.02567 to 0.02340, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.5274e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0234 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/1000
# Epoch 00036: val_loss improved from 0.02340 to 0.02145, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.6077e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0214 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/1000
# Epoch 00037: val_loss improved from 0.02145 to 0.01969, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.7509e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0197 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/1000
# Epoch 00038: val_loss improved from 0.01969 to 0.01807, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.4156e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0181 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/1000
# Epoch 00039: val_loss improved from 0.01807 to 0.01662, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.5704e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0166 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/1000
# Epoch 00040: val_loss improved from 0.01662 to 0.01535, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3411e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0153 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/1000
# Epoch 00041: val_loss improved from 0.01535 to 0.01415, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 4.6566e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0141 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/1000
# Epoch 00042: val_loss improved from 0.01415 to 0.01304, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.5646e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0130 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/1000
# Epoch 00043: val_loss improved from 0.01304 to 0.01205, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3784e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0121 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/1000
# Epoch 00044: val_loss improved from 0.01205 to 0.01118, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.8254e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0112 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/1000
# Epoch 00045: val_loss improved from 0.01118 to 0.01037, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.4587e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0104 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/1000
# Epoch 00046: val_loss improved from 0.01037 to 0.00960, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 4.7684e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0096 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/1000
# Epoch 00047: val_loss improved from 0.00960 to 0.00890, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.6764e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0089 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/1000
# Epoch 00048: val_loss improved from 0.00890 to 0.00828, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0083 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/1000
# Epoch 00049: val_loss improved from 0.00828 to 0.00772, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0077 - val_sparse_categorical_accuracy: 1.0000
# Epoch 51/1000
# Epoch 00050: val_loss improved from 0.00772 to 0.00720, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3411e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0072 - val_sparse_categorical_accuracy: 1.0000
# Epoch 52/1000
# Epoch 00051: val_loss improved from 0.00720 to 0.00673, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0067 - val_sparse_categorical_accuracy: 1.0000
# Epoch 53/1000
# Epoch 00052: val_loss improved from 0.00673 to 0.00630, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.4901e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0063 - val_sparse_categorical_accuracy: 1.0000
# Epoch 54/1000
# Epoch 00053: val_loss improved from 0.00630 to 0.00590, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.4156e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0059 - val_sparse_categorical_accuracy: 1.0000
# Epoch 55/1000
# Epoch 00054: val_loss improved from 0.00590 to 0.00551, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0055 - val_sparse_categorical_accuracy: 1.0000
# Epoch 56/1000
# Epoch 00055: val_loss improved from 0.00551 to 0.00518, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3784e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0052 - val_sparse_categorical_accuracy: 1.0000
# Epoch 57/1000
# Epoch 00056: val_loss improved from 0.00518 to 0.00487, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.5274e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0049 - val_sparse_categorical_accuracy: 1.0000
# Epoch 58/1000
# Epoch 00057: val_loss improved from 0.00487 to 0.00457, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3411e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0046 - val_sparse_categorical_accuracy: 1.0000
# Epoch 59/1000
# Epoch 00058: val_loss improved from 0.00457 to 0.00430, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0043 - val_sparse_categorical_accuracy: 1.0000
# Epoch 60/1000
# Epoch 00059: val_loss improved from 0.00430 to 0.00405, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.4959e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0040 - val_sparse_categorical_accuracy: 1.0000
# Epoch 61/1000
# Epoch 00060: val_loss improved from 0.00405 to 0.00382, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0038 - val_sparse_categorical_accuracy: 1.0000
# Epoch 62/1000
# Epoch 00061: val_loss improved from 0.00382 to 0.00360, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3039e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0036 - val_sparse_categorical_accuracy: 1.0000
# Epoch 63/1000
# Epoch 00062: val_loss improved from 0.00360 to 0.00340, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3039e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0034 - val_sparse_categorical_accuracy: 1.0000
# Epoch 64/1000
# Epoch 00063: val_loss improved from 0.00340 to 0.00321, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 1.0000
# Epoch 65/1000
# Epoch 00064: val_loss improved from 0.00321 to 0.00304, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.7509e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 1.0000
# Epoch 66/1000
# Epoch 00065: val_loss improved from 0.00304 to 0.00288, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 1.0000
# Epoch 67/1000
# Epoch 00066: val_loss improved from 0.00288 to 0.00272, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0027 - val_sparse_categorical_accuracy: 1.0000
# Epoch 68/1000
# Epoch 00067: val_loss improved from 0.00272 to 0.00259, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3039e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0026 - val_sparse_categorical_accuracy: 1.0000
# Epoch 69/1000
# Epoch 00068: val_loss improved from 0.00259 to 0.00245, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 3.3155e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0025 - val_sparse_categorical_accuracy: 1.0000
# Epoch 70/1000
# Epoch 00069: val_loss improved from 0.00245 to 0.00233, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 1.0000
# Epoch 71/1000
# Epoch 00070: val_loss improved from 0.00233 to 0.00221, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 3.7998e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 1.0000
# Epoch 72/1000
# Epoch 00071: val_loss improved from 0.00221 to 0.00210, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 1.0000
# Epoch 73/1000
# Epoch 00072: val_loss improved from 0.00210 to 0.00200, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 4.2096e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0020 - val_sparse_categorical_accuracy: 1.0000
# Epoch 74/1000
# Epoch 00073: val_loss improved from 0.00200 to 0.00191, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.4901e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 75/1000
# Epoch 00074: val_loss improved from 0.00191 to 0.00182, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 3.6880e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 76/1000
# Epoch 00075: val_loss improved from 0.00182 to 0.00174, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.3842e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0017 - val_sparse_categorical_accuracy: 1.0000
# Epoch 77/1000
# Epoch 00076: val_loss improved from 0.00174 to 0.00166, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.4901e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0017 - val_sparse_categorical_accuracy: 1.0000
# Epoch 78/1000
# Epoch 00077: val_loss improved from 0.00166 to 0.00159, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0016 - val_sparse_categorical_accuracy: 1.0000
# Epoch 79/1000
# Epoch 00078: val_loss improved from 0.00159 to 0.00152, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0015 - val_sparse_categorical_accuracy: 1.0000
# Epoch 80/1000
# Epoch 00079: val_loss improved from 0.00152 to 0.00145, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 6.5937e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0014 - val_sparse_categorical_accuracy: 1.0000
# Epoch 81/1000
# Epoch 00080: val_loss improved from 0.00145 to 0.00139, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.8626e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0014 - val_sparse_categorical_accuracy: 1.0000
# Epoch 82/1000
# Epoch 00081: val_loss improved from 0.00139 to 0.00133, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.8312e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000
# Epoch 83/1000
# Epoch 00082: val_loss improved from 0.00133 to 0.00128, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000
# Epoch 84/1000
# Epoch 00083: val_loss improved from 0.00128 to 0.00122, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3411e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 85/1000
# Epoch 00084: val_loss improved from 0.00122 to 0.00117, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.7509e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 86/1000
# Epoch 00085: val_loss improved from 0.00117 to 0.00113, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 87/1000
# Epoch 00086: val_loss improved from 0.00113 to 0.00108, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.0862e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 88/1000
# Epoch 00087: val_loss improved from 0.00108 to 0.00104, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 89/1000
# Epoch 00088: val_loss improved from 0.00104 to 0.00100, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.5646e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 9.9883e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 90/1000
# Epoch 00089: val_loss improved from 0.00100 to 0.00096, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.4529e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 9.6193e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 91/1000
# Epoch 00090: val_loss improved from 0.00096 to 0.00092, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3039e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 9.2415e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 92/1000
# Epoch 00091: val_loss improved from 0.00092 to 0.00089, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3411e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 8.8993e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 93/1000
# Epoch 00092: val_loss improved from 0.00089 to 0.00086, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.6019e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 8.5803e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 94/1000
# Epoch 00093: val_loss improved from 0.00086 to 0.00083, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 8.2700e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 95/1000
# Epoch 00094: val_loss improved from 0.00083 to 0.00080, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.1234e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 7.9710e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 96/1000
# Epoch 00095: val_loss improved from 0.00080 to 0.00077, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 7.6988e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 97/1000
# Epoch 00096: val_loss improved from 0.00077 to 0.00074, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.5704e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 7.4433e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 98/1000
# Epoch 00097: val_loss improved from 0.00074 to 0.00072, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 7.1840e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 99/1000
# Epoch 00098: val_loss improved from 0.00072 to 0.00069, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 6.9490e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 100/1000
# Epoch 00099: val_loss improved from 0.00069 to 0.00067, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.5274e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 6.7250e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 101/1000
# Epoch 00100: val_loss improved from 0.00067 to 0.00065, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 6.5052e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 102/1000
# Epoch 00101: val_loss improved from 0.00065 to 0.00063, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3411e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 6.2964e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 103/1000
# Epoch 00102: val_loss improved from 0.00063 to 0.00061, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.4587e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 6.1055e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 104/1000
# Epoch 00103: val_loss improved from 0.00061 to 0.00059, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 5.9072e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 105/1000
# Epoch 00104: val_loss improved from 0.00059 to 0.00057, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 5.7177e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 106/1000
# Epoch 00105: val_loss improved from 0.00057 to 0.00055, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.1607e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 5.5418e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 107/1000
# Epoch 00106: val_loss improved from 0.00055 to 0.00054, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 3.0547e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 5.3736e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 108/1000
# Epoch 00107: val_loss improved from 0.00054 to 0.00052, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 5.2067e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 109/1000
# Epoch 00108: val_loss improved from 0.00052 to 0.00051, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.7136e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 5.0505e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 110/1000
# Epoch 00109: val_loss improved from 0.00051 to 0.00049, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.8999e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.9053e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 111/1000
# Epoch 00110: val_loss improved from 0.00049 to 0.00048, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.4959e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7663e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 112/1000
# Epoch 00111: val_loss improved from 0.00048 to 0.00046, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.6228e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 113/1000
# Epoch 00112: val_loss improved from 0.00046 to 0.00045, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.4156e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.4832e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 114/1000
# Epoch 00113: val_loss improved from 0.00045 to 0.00044, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 4.0606e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.3624e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 115/1000
# Epoch 00114: val_loss improved from 0.00044 to 0.00042, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.5274e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.2425e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 116/1000
# Epoch 00115: val_loss improved from 0.00042 to 0.00041, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.5646e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.1223e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 117/1000
# Epoch 00116: val_loss improved from 0.00041 to 0.00040, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.5274e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.0103e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 118/1000
# Epoch 00117: val_loss improved from 0.00040 to 0.00039, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3784e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.9054e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 119/1000
# Epoch 00118: val_loss improved from 0.00039 to 0.00038, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.7956e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 120/1000
# Epoch 00119: val_loss improved from 0.00038 to 0.00037, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 6.1094e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.6991e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 121/1000
# Epoch 00120: val_loss improved from 0.00037 to 0.00036, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.4156e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.6036e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 122/1000
# Epoch 00121: val_loss improved from 0.00036 to 0.00035, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3784e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.5080e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 123/1000
# Epoch 00122: val_loss improved from 0.00035 to 0.00034, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.5274e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.4179e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 124/1000
# Epoch 00123: val_loss improved from 0.00034 to 0.00033, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.3309e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 125/1000
# Epoch 00124: val_loss improved from 0.00033 to 0.00033, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3411e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.2505e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 126/1000
# Epoch 00125: val_loss improved from 0.00033 to 0.00032, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.1715e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 127/1000
# Epoch 00126: val_loss improved from 0.00032 to 0.00031, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.7136e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.0978e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 128/1000
# Epoch 00127: val_loss improved from 0.00031 to 0.00030, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.0248e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 129/1000
# Epoch 00128: val_loss improved from 0.00030 to 0.00029, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.6391e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.9492e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 130/1000
# Epoch 00129: val_loss improved from 0.00029 to 0.00029, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.5274e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.8844e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 131/1000
# Epoch 00130: val_loss improved from 0.00029 to 0.00028, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.4529e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.8232e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 132/1000
# Epoch 00131: val_loss improved from 0.00028 to 0.00028, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.4901e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.7617e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 133/1000
# Epoch 00132: val_loss improved from 0.00028 to 0.00027, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.2724e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.6985e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 134/1000
# Epoch 00133: val_loss improved from 0.00027 to 0.00026, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.4901e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.6363e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 135/1000
# Epoch 00134: val_loss improved from 0.00026 to 0.00026, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.8626e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.5797e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 136/1000
# Epoch 00135: val_loss improved from 0.00026 to 0.00025, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.5274e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.5236e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 137/1000
# Epoch 00136: val_loss improved from 0.00025 to 0.00025, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3039e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.4685e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 138/1000
# Epoch 00137: val_loss improved from 0.00025 to 0.00024, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.0117e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.4173e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 139/1000
# Epoch 00138: val_loss improved from 0.00024 to 0.00024, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 3.0175e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.3663e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 140/1000
# Epoch 00139: val_loss improved from 0.00024 to 0.00023, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.3145e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 141/1000
# Epoch 00140: val_loss improved from 0.00023 to 0.00023, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.9057e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.2664e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 142/1000
# Epoch 00141: val_loss improved from 0.00023 to 0.00022, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3411e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.2218e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 143/1000
# Epoch 00142: val_loss improved from 0.00022 to 0.00022, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.1807e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 144/1000
# Epoch 00143: val_loss improved from 0.00022 to 0.00021, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 3.3900e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.1427e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 145/1000
# Epoch 00144: val_loss improved from 0.00021 to 0.00021, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3039e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.1013e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 146/1000
# Epoch 00145: val_loss improved from 0.00021 to 0.00021, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.5274e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.0627e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 147/1000
# Epoch 00146: val_loss improved from 0.00021 to 0.00020, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.4959e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.0240e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 148/1000
# Epoch 00147: val_loss improved from 0.00020 to 0.00020, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.4529e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.9875e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 149/1000
# Epoch 00148: val_loss improved from 0.00020 to 0.00020, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.9505e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 150/1000
# Epoch 00149: val_loss improved from 0.00020 to 0.00019, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.9171e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 151/1000
# Epoch 00150: val_loss improved from 0.00019 to 0.00019, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.8844e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 152/1000
# Epoch 00151: val_loss improved from 0.00019 to 0.00019, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.4529e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.8506e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 153/1000
# Epoch 00152: val_loss improved from 0.00019 to 0.00018, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.5274e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.8164e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 154/1000
# Epoch 00153: val_loss improved from 0.00018 to 0.00018, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3039e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.7851e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 155/1000
# Epoch 00154: val_loss improved from 0.00018 to 0.00018, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3039e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.7542e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 156/1000
# Epoch 00155: val_loss improved from 0.00018 to 0.00017, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.7200e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 157/1000
# Epoch 00156: val_loss improved from 0.00017 to 0.00017, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.8999e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.6896e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 158/1000
# Epoch 00157: val_loss improved from 0.00017 to 0.00017, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.6613e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 159/1000
# Epoch 00158: val_loss improved from 0.00017 to 0.00016, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 5.6624e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.6344e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 160/1000
# Epoch 00159: val_loss improved from 0.00016 to 0.00016, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3039e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.6055e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 161/1000
# Epoch 00160: val_loss improved from 0.00016 to 0.00016, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3784e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5760e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 162/1000
# Epoch 00161: val_loss improved from 0.00016 to 0.00016, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5505e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 163/1000
# Epoch 00162: val_loss improved from 0.00016 to 0.00015, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.6391e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5258e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 164/1000
# Epoch 00163: val_loss improved from 0.00015 to 0.00015, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5046e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 165/1000
# Epoch 00164: val_loss improved from 0.00015 to 0.00015, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.4830e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 166/1000
# Epoch 00165: val_loss improved from 0.00015 to 0.00015, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.4595e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 167/1000
# Epoch 00166: val_loss improved from 0.00015 to 0.00014, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.4365e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 168/1000
# Epoch 00167: val_loss improved from 0.00014 to 0.00014, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.6391e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.4163e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 169/1000
# Epoch 00168: val_loss improved from 0.00014 to 0.00014, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.3469e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.3915e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 170/1000
# Epoch 00169: val_loss improved from 0.00014 to 0.00014, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.3701e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 171/1000
# Epoch 00170: val_loss improved from 0.00014 to 0.00013, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.3479e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 172/1000
# Epoch 00171: val_loss improved from 0.00013 to 0.00013, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.8999e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.3273e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 173/1000
# Epoch 00172: val_loss improved from 0.00013 to 0.00013, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.4156e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.3084e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 174/1000
# Epoch 00173: val_loss improved from 0.00013 to 0.00013, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.3097e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2886e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 175/1000
# Epoch 00174: val_loss improved from 0.00013 to 0.00013, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.4156e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2708e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 176/1000
# Epoch 00175: val_loss improved from 0.00013 to 0.00013, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 3.8743e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2530e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 177/1000
# Epoch 00176: val_loss improved from 0.00013 to 0.00012, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2373e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 178/1000
# Epoch 00177: val_loss improved from 0.00012 to 0.00012, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2199e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 179/1000
# Epoch 00178: val_loss improved from 0.00012 to 0.00012, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.7509e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2022e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 180/1000
# Epoch 00179: val_loss improved from 0.00012 to 0.00012, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 3.6135e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1858e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 181/1000
# Epoch 00180: val_loss improved from 0.00012 to 0.00012, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.4156e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1710e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 182/1000
# Epoch 00181: val_loss improved from 0.00012 to 0.00012, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.5274e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1582e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 183/1000
# Epoch 00182: val_loss improved from 0.00012 to 0.00011, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.7136e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1429e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 184/1000
# Epoch 00183: val_loss improved from 0.00011 to 0.00011, saving model to model10.h5
# ...
# Epoch 931/1000
# Epoch 00930: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.3411e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.9919e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 932/1000
# Epoch 00931: val_loss improved from 0.00000 to 0.00000, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.3842e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.9621e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 933/1000
# Epoch 00932: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.9621e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 934/1000
# Epoch 00933: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.9621e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 935/1000
# Epoch 00934: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.8999e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.9621e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 936/1000
# Epoch 00935: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.9621e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 937/1000
# Epoch 00936: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.4529e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.9621e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 938/1000
# Epoch 00937: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.8254e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.9621e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 939/1000
# Epoch 00938: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.9621e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 940/1000
# Epoch 00939: val_loss improved from 0.00000 to 0.00000, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 4.3958e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.9472e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 941/1000
# Epoch 00940: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.9472e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 942/1000
# Epoch 00941: val_loss improved from 0.00000 to 0.00000, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 2.3842e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.9323e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 943/1000
# Epoch 00942: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.4529e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.9323e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 944/1000
# Epoch 00943: val_loss improved from 0.00000 to 0.00000, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.9174e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 945/1000
# Epoch 00944: val_loss improved from 0.00000 to 0.00000, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.4901e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8876e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 946/1000
# Epoch 00945: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8876e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 947/1000
# Epoch 00946: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8876e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 948/1000
# Epoch 00947: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 6.1095e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8876e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 949/1000
# Epoch 00948: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8876e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 950/1000
# Epoch 00949: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 5.6252e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8876e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 951/1000
# Epoch 00950: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8876e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 952/1000
# Epoch 00951: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 2.3842e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8876e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 953/1000
# Epoch 00952: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8876e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 954/1000
# Epoch 00953: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.4156e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8876e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 955/1000
# Epoch 00954: val_loss improved from 0.00000 to 0.00000, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8727e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 956/1000
# Epoch 00955: val_loss improved from 0.00000 to 0.00000, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8429e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 957/1000
# Epoch 00956: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.8254e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8429e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 958/1000
# Epoch 00957: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.4156e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8429e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 959/1000
# Epoch 00958: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.4156e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8429e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 960/1000
# Epoch 00959: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8429e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 961/1000
# Epoch 00960: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.3784e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8429e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 962/1000
# Epoch 00961: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.3039e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8429e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 963/1000
# Epoch 00962: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8429e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 964/1000
# Epoch 00963: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8429e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 965/1000
# Epoch 00964: val_loss improved from 0.00000 to 0.00000, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3039e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8280e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 966/1000
# Epoch 00965: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8280e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 967/1000
# Epoch 00966: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 3.6135e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8280e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 968/1000
# Epoch 00967: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.4901e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8280e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 969/1000
# Epoch 00968: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.3039e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8280e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 970/1000
# Epoch 00969: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8280e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 971/1000
# Epoch 00970: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.3784e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.8280e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 972/1000
# Epoch 00971: val_loss improved from 0.00000 to 0.00000, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7833e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 973/1000
# Epoch 00972: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.3411e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7833e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 974/1000
# Epoch 00973: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7833e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 975/1000
# Epoch 00974: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 2.0117e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7833e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 976/1000
# Epoch 00975: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.4156e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7833e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 977/1000
# Epoch 00976: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7833e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 978/1000
# Epoch 00977: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7833e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 979/1000
# Epoch 00978: val_loss improved from 0.00000 to 0.00000, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.8999e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7684e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 980/1000
# Epoch 00979: val_loss improved from 0.00000 to 0.00000, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.3039e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7535e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 981/1000
# Epoch 00980: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.6391e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7535e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 982/1000
# Epoch 00981: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.5274e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7535e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 983/1000
# Epoch 00982: val_loss improved from 0.00000 to 0.00000, saving model to model10.h5
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7386e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 984/1000
# Epoch 00983: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7535e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 985/1000
# Epoch 00984: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.8254e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7386e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 986/1000
# Epoch 00985: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 2.1607e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7386e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 987/1000
# Epoch 00986: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 3.4273e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7386e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 988/1000
# Epoch 00987: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.3039e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7386e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 989/1000
# Epoch 00988: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 2.1607e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7386e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 990/1000
# Epoch 00989: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.8254e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7386e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 991/1000
# Epoch 00990: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.6391e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7386e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 992/1000
# Epoch 00991: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7386e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 993/1000
# Epoch 00992: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7386e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 994/1000
# Epoch 00993: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7386e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 995/1000
# Epoch 00994: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7386e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 996/1000
# Epoch 00995: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 4.8429e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7386e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 997/1000
# Epoch 00996: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.4156e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7386e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 998/1000
# Epoch 00997: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.2293e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7386e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 999/1000
# Epoch 00998: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.4901e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7386e-06 - val_sparse_categorical_accuracy: 1.0000
# Epoch 1000/1000
# Epoch 00999: val_loss did not improve
# 32/32 [==============================] - 0s - loss: 1.2666e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.7386e-06 - val_sparse_categorical_accuracy: 1.0000

# %%
from keras.models import load_model
trained_model = load_model(model_name)
print(trained_model.metrics_names)
trained_model.evaluate(x=X_train, y=y_train)
# Out:
# ['loss', 'sparse_categorical_accuracy']
# 32/32 [==============================] - 0s
# [4.9769741963245906e-06, 1.0]

# %%
trained_model.evaluate(x=X_val, y=y_val)
# Out:
# 8/8 [==============================] - 0s
# [4.7385574362124316e-06, 1.0]
