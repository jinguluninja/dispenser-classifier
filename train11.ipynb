# %%
import os
import keras
import numpy as np
np.random.seed(135109)
# Out:
# Using TensorFlow backend.

# %%
sensor = '11'

# %%
def dataset():
    X = []
    y = []
    data_dir_0 = sorted(os.listdir(os.path.join('pac_data', sensor, '0')))   
    i = 0
    for f in data_dir_0:
        if i % 100 == 0: print(i)
        i += 1
        X.append(np.load(os.path.join('pac_data', sensor, '0', f))['x'])
        y.append(0)
    X = np.asarray(X, dtype=np.float16)
    y = np.asarray(y, dtype=int)
    indices = np.arange(y.shape[0])
    np.random.shuffle(indices)
    X_train = X[indices[:int(0.8*len(indices))]]
    y_train = y[indices[:int(0.8*len(indices))]]
    X_val = X[indices[int(0.8*len(indices)):]]
    y_val = y[indices[int(0.8*len(indices)):]]
    labels_present = os.listdir(os.path.join('pac_data', sensor))
    if '1' in labels_present:
        X = []
        y = []
        data_dir_1 = sorted(os.listdir(os.path.join('pac_data', sensor, '1')))
        i = 0
        for f in data_dir_1:
            if i % 100 == 0: print(i)
            i += 1
            X.append(np.load(os.path.join('pac_data', sensor, '1', f))['x'])
            y.append(1)        
        X = np.asarray(X, dtype=np.float16)
        y = np.asarray(y, dtype=int)
        indices = np.arange(y.shape[0])
        np.random.shuffle(indices)
        X_train = np.concatenate([X_train, X[indices[:int(0.8*len(indices))]]])
        y_train = np.concatenate([y_train, y[indices[:int(0.8*len(indices))]]])
        X_val = np.concatenate([X_val, X[indices[int(0.8*len(indices)):]]])
        y_val = np.concatenate([y_val, y[indices[int(0.8*len(indices)):]]])
    X_train = np.expand_dims(np.asarray(X_train, dtype=np.float16), axis=3)
    y_train = np.asarray(y_train, dtype=int)
    X_val = np.expand_dims(np.asarray(X_val, dtype=np.float16), axis=3)
    y_val = np.asarray(y_val, dtype=int)
    X_train /= 5.
    X_val /= 5.
    mean_arr = np.mean(X_train, axis = 0)
    np.save(os.path.join('pac_data', sensor, 'mean.npy'), mean_arr)
    X_train -= mean_arr 
    X_val -= mean_arr  
    return X_train, y_train, X_val, y_val

# %%
X_train, y_train, X_val, y_val = dataset()
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 0
# 100
# 200
# 300
# 400
# 500

# %%
print(X_train.shape, y_train.shape, X_val.shape, y_val.shape)
# Out:
# (11231, 240, 320, 1) (11231,) (2809, 240, 320, 1) (2809,)

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/gpu:0']

# %%
from keras.models import Sequential
from keras.layers import TimeDistributed, GlobalAveragePooling2D, Activation, Dense, Input
from keras.layers import BatchNormalization, Conv2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D
from keras.layers import GlobalMaxPooling2D
from keras.layers.recurrent import LSTM
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras.layers import Dropout, Flatten
from keras.layers import concatenate
from keras import regularizers
from keras import initializers
from keras import constraints
from keras.models import Model
from keras import backend as K
from keras.utils.layer_utils import convert_all_kernels_in_model
from keras.utils.data_utils import get_file
from keras.utils import conv_utils
from keras.engine.topology import get_source_inputs
from keras.engine import InputSpec
from keras.applications.xception import Xception
from keras import metrics

# %%
#linear
def linear(dropout):
    inputs = Input(shape=(240, 320, 1))
    x = Flatten()(inputs)
    x = Dropout(dropout)(x)
    x = Dense(2, activation='softmax')(x)
    model = Model(inputs, x, name='linear')
    return model

# %%
from keras import layers
from keras.layers import Activation
from keras.layers import SeparableConv2D

def xception(dropout):
    inputs = Input(shape=(240, 320, 1))    

    x = Conv2D(32, (3, 3), padding='same', strides=(2, 2), use_bias=False, name='block1_conv1')(inputs)
    x = BatchNormalization(name='block1_conv1_bn')(x)
    x = Activation('relu', name='block1_conv1_act')(x)
    x = Conv2D(64, (3, 3), padding='same', use_bias=False, name='block1_conv2')(x)
    x = BatchNormalization(name='block1_conv2_bn')(x)
    x = Activation('relu', name='block1_conv2_act')(x)

    residual = Conv2D(128, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, name='block2_sepconv1')(x)
    x = BatchNormalization(name='block2_sepconv1_bn')(x)
    x = Activation('relu', name='block2_sepconv2_act')(x)
    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, name='block2_sepconv2')(x)
    x = BatchNormalization(name='block2_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block2_pool')(x)
    x = layers.add([x, residual])

    residual = Conv2D(256, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block3_sepconv1_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, name='block3_sepconv1')(x)
    x = BatchNormalization(name='block3_sepconv1_bn')(x)
    x = Activation('relu', name='block3_sepconv2_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, name='block3_sepconv2')(x)
    x = BatchNormalization(name='block3_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block3_pool')(x)
    x = layers.add([x, residual])

    residual = Conv2D(728, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block4_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name='block4_sepconv1')(x)
    x = BatchNormalization(name='block4_sepconv1_bn')(x)
    x = Activation('relu', name='block4_sepconv2_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name='block4_sepconv2')(x)
    x = BatchNormalization(name='block4_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block4_pool')(x)
    x = layers.add([x, residual])

    for i in range(8):
        residual = x
        prefix = 'block' + str(i + 5)

        x = Activation('relu', name=prefix + '_sepconv1_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name=prefix + '_sepconv1')(x)
        x = BatchNormalization(name=prefix + '_sepconv1_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv2_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name=prefix + '_sepconv2')(x)
        x = BatchNormalization(name=prefix + '_sepconv2_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv3_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name=prefix + '_sepconv3')(x)
        x = BatchNormalization(name=prefix + '_sepconv3_bn')(x)

        x = layers.add([x, residual])

    residual = Conv2D(1024, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block13_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name='block13_sepconv1')(x)
    x = BatchNormalization(name='block13_sepconv1_bn')(x)
    x = Activation('relu', name='block13_sepconv2_act')(x)
    x = SeparableConv2D(1024, (3, 3), padding='same', use_bias=False, name='block13_sepconv2')(x)
    x = BatchNormalization(name='block13_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block13_pool')(x)
    x = layers.add([x, residual])

    x = SeparableConv2D(1536, (3, 3), padding='same', use_bias=False, name='block14_sepconv1')(x)
    x = BatchNormalization(name='block14_sepconv1_bn')(x)
    x = Activation('relu', name='block14_sepconv1_act')(x)

    x = SeparableConv2D(2048, (3, 3), padding='same', use_bias=False, name='block14_sepconv2')(x)
    x = BatchNormalization(name='block14_sepconv2_bn')(x)
    x = Activation('relu', name='block14_sepconv2_act')(x)

    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dropout(dropout)(x)
    x = Dense(2, activation='softmax', name='predictions')(x)
    model = Model(inputs, x, name='xception')
    return model


'''
def xception(dropout):
    base_model = Xception(include_top=False, input_shape = (240, 320, 1), pooling='avg')
    x = base_model.output
    x = Flatten()(x)
    x = Dropout(dropout)(x) # drop prob
    predictions = Dense(2, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions, name='linear')
    return model
'''
# Out:
# "\ndef xception(dropout):\n    base_model = Xception(include_top=False, input_shape = (240, 320, 1), pooling='avg')\n    x = base_model.output\n    x = Flatten()(x)\n    x = Dropout(dropout)(x) # drop prob\n    predictions = Dense(2, activation='softmax')(x)\n    model = Model(inputs=base_model.input, outputs=predictions, name='linear')\n    return model\n"

# %%
def vanillacnn(dropout):
    inputs = Input(shape=(240, 320, 1)) 
    x = Conv2D(32, (3, 3), strides=(2, 2), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = Dropout(dropout)(x)
    
    x = Conv2D(64, (3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = Dropout(dropout)(x)
    
    x = Conv2D(128, (3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = Dropout(dropout)(x)
    
    x = Conv2D(256, (3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    
    x = Flatten()(x)
    x = Dropout(dropout)(x)
    x = Dense(2, activation='softmax', name='predictions')(x)
    model = Model(inputs, x, name='xception')
    return model

# %%
model_name = 'model' + sensor + '.h5'
model = vanillacnn(0.5)

adam = keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=[metrics.sparse_categorical_accuracy])


checkpoint = ModelCheckpoint(model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
stop = EarlyStopping(patience=20, verbose=1)

callbacks_list = [checkpoint, stop]

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 240, 320, 1)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 120, 160, 32)      320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 120, 160, 32)      128
# _________________________________________________________________
# activation_1 (Activation)    (None, 120, 160, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 60, 80, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60, 80, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 40, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 30, 40, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 40, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 15, 20, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 15, 20, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 10, 128)        73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 10, 128)        512
# _________________________________________________________________
# activation_3 (Activation)    (None, 8, 10, 128)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 5, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 5, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 3, 256)         295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2, 3, 256)         1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 2, 3, 256)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 2, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# predictions (Dense)          (None, 2)                 1026
# =================================================================
# Total params: 390,786
# Trainable params: 389,826
# Non-trainable params: 960
# _________________________________________________________________

# %%
model.fit(x=X_train, 
          y=y_train, 
          batch_size=32, 
          epochs=1000, 
          verbose=1, 
          callbacks=callbacks_list, 
          validation_data=(X_val, y_val), 
          shuffle=True)
# Out:
# Train on 11231 samples, validate on 2809 samples
# Epoch 1/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.1526 - sparse_categorical_accuracy: 0.9595Epoch 00000: val_loss improved from inf to 0.35756, saving model to model11.h5
# 11231/11231 [==============================] - 37s - loss: 0.1522 - sparse_categorical_accuracy: 0.9596 - val_loss: 0.3576 - val_sparse_categorical_accuracy: 0.9616
# Epoch 2/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0777 - sparse_categorical_accuracy: 0.9731Epoch 00001: val_loss improved from 0.35756 to 0.03726, saving model to model11.h5
# 11231/11231 [==============================] - 35s - loss: 0.0776 - sparse_categorical_accuracy: 0.9732 - val_loss: 0.0373 - val_sparse_categorical_accuracy: 0.9872
# Epoch 3/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0637 - sparse_categorical_accuracy: 0.9777Epoch 00002: val_loss improved from 0.03726 to 0.02192, saving model to model11.h5
# 11231/11231 [==============================] - 36s - loss: 0.0637 - sparse_categorical_accuracy: 0.9777 - val_loss: 0.0219 - val_sparse_categorical_accuracy: 0.9918
# Epoch 4/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0463 - sparse_categorical_accuracy: 0.9826Epoch 00003: val_loss improved from 0.02192 to 0.01582, saving model to model11.h5
# 11231/11231 [==============================] - 36s - loss: 0.0463 - sparse_categorical_accuracy: 0.9826 - val_loss: 0.0158 - val_sparse_categorical_accuracy: 0.9950
# Epoch 5/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0413 - sparse_categorical_accuracy: 0.9862Epoch 00004: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0412 - sparse_categorical_accuracy: 0.9862 - val_loss: 0.0170 - val_sparse_categorical_accuracy: 0.9943
# Epoch 6/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0358 - sparse_categorical_accuracy: 0.9878Epoch 00005: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0357 - sparse_categorical_accuracy: 0.9878 - val_loss: 0.0187 - val_sparse_categorical_accuracy: 0.9950
# Epoch 7/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0317 - sparse_categorical_accuracy: 0.9880Epoch 00006: val_loss improved from 0.01582 to 0.01441, saving model to model11.h5
# 11231/11231 [==============================] - 35s - loss: 0.0316 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.0144 - val_sparse_categorical_accuracy: 0.9950
# Epoch 8/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0320 - sparse_categorical_accuracy: 0.9879Epoch 00007: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0319 - sparse_categorical_accuracy: 0.9880 - val_loss: 0.0469 - val_sparse_categorical_accuracy: 0.9922
# Epoch 9/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0301 - sparse_categorical_accuracy: 0.9906Epoch 00008: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0301 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.0147 - val_sparse_categorical_accuracy: 0.9947
# Epoch 10/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0247 - sparse_categorical_accuracy: 0.9917Epoch 00009: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0247 - sparse_categorical_accuracy: 0.9917 - val_loss: 0.0159 - val_sparse_categorical_accuracy: 0.9943
# Epoch 11/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0269 - sparse_categorical_accuracy: 0.9904Epoch 00010: val_loss improved from 0.01441 to 0.01426, saving model to model11.h5
# 11231/11231 [==============================] - 35s - loss: 0.0269 - sparse_categorical_accuracy: 0.9905 - val_loss: 0.0143 - val_sparse_categorical_accuracy: 0.9943
# Epoch 12/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0246 - sparse_categorical_accuracy: 0.9919Epoch 00011: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0245 - sparse_categorical_accuracy: 0.9919 - val_loss: 0.0154 - val_sparse_categorical_accuracy: 0.9954
# Epoch 13/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0262 - sparse_categorical_accuracy: 0.9912Epoch 00012: val_loss improved from 0.01426 to 0.01417, saving model to model11.h5
# 11231/11231 [==============================] - 36s - loss: 0.0261 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0142 - val_sparse_categorical_accuracy: 0.9961
# Epoch 14/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0236 - sparse_categorical_accuracy: 0.9914Epoch 00013: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0236 - sparse_categorical_accuracy: 0.9914 - val_loss: 0.0156 - val_sparse_categorical_accuracy: 0.9943
# Epoch 15/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0236 - sparse_categorical_accuracy: 0.9921Epoch 00014: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0237 - sparse_categorical_accuracy: 0.9920 - val_loss: 0.0236 - val_sparse_categorical_accuracy: 0.9922
# Epoch 16/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0241 - sparse_categorical_accuracy: 0.9922Epoch 00015: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0240 - sparse_categorical_accuracy: 0.9923 - val_loss: 0.0166 - val_sparse_categorical_accuracy: 0.9943
# Epoch 17/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0187 - sparse_categorical_accuracy: 0.9941Epoch 00016: val_loss improved from 0.01417 to 0.01246, saving model to model11.h5
# 11231/11231 [==============================] - 35s - loss: 0.0187 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.0125 - val_sparse_categorical_accuracy: 0.9957
# Epoch 18/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0200 - sparse_categorical_accuracy: 0.9929Epoch 00017: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0199 - sparse_categorical_accuracy: 0.9929 - val_loss: 0.0137 - val_sparse_categorical_accuracy: 0.9950
# Epoch 19/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0211 - sparse_categorical_accuracy: 0.9928Epoch 00018: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0215 - sparse_categorical_accuracy: 0.9927 - val_loss: 0.0165 - val_sparse_categorical_accuracy: 0.9936
# Epoch 20/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0196 - sparse_categorical_accuracy: 0.9938Epoch 00019: val_loss improved from 0.01246 to 0.01184, saving model to model11.h5
# 11231/11231 [==============================] - 35s - loss: 0.0195 - sparse_categorical_accuracy: 0.9938 - val_loss: 0.0118 - val_sparse_categorical_accuracy: 0.9961
# Epoch 21/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0174 - sparse_categorical_accuracy: 0.9939Epoch 00020: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0174 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.0153 - val_sparse_categorical_accuracy: 0.9954
# Epoch 22/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0175 - sparse_categorical_accuracy: 0.9941Epoch 00021: val_loss improved from 0.01184 to 0.01151, saving model to model11.h5
# 11231/11231 [==============================] - 35s - loss: 0.0175 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.0115 - val_sparse_categorical_accuracy: 0.9957
# Epoch 23/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0180 - sparse_categorical_accuracy: 0.9938Epoch 00022: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0180 - sparse_categorical_accuracy: 0.9938 - val_loss: 0.0221 - val_sparse_categorical_accuracy: 0.9918
# Epoch 24/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0175 - sparse_categorical_accuracy: 0.9937Epoch 00023: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0175 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0120 - val_sparse_categorical_accuracy: 0.9957
# Epoch 25/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0139 - sparse_categorical_accuracy: 0.9954Epoch 00024: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0141 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.0133 - val_sparse_categorical_accuracy: 0.9954
# Epoch 26/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0171 - sparse_categorical_accuracy: 0.9943Epoch 00025: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0171 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.0146 - val_sparse_categorical_accuracy: 0.9954
# Epoch 27/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0167 - sparse_categorical_accuracy: 0.9951Epoch 00026: val_loss did not improve
# 11231/11231 [==============================] - 36s - loss: 0.0167 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.0118 - val_sparse_categorical_accuracy: 0.9961
# Epoch 28/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0111 - sparse_categorical_accuracy: 0.9962Epoch 00027: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0110 - sparse_categorical_accuracy: 0.9963 - val_loss: 0.0131 - val_sparse_categorical_accuracy: 0.9964
# Epoch 29/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0177 - sparse_categorical_accuracy: 0.9946Epoch 00028: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0176 - sparse_categorical_accuracy: 0.9947 - val_loss: 0.0116 - val_sparse_categorical_accuracy: 0.9961
# Epoch 30/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0125 - sparse_categorical_accuracy: 0.9954Epoch 00029: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0125 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.0132 - val_sparse_categorical_accuracy: 0.9954
# Epoch 31/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0150 - sparse_categorical_accuracy: 0.9954Epoch 00030: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0149 - sparse_categorical_accuracy: 0.9954 - val_loss: 0.0117 - val_sparse_categorical_accuracy: 0.9964
# Epoch 32/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0156 - sparse_categorical_accuracy: 0.9954Epoch 00031: val_loss did not improve
# 11231/11231 [==============================] - 36s - loss: 0.0156 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.0118 - val_sparse_categorical_accuracy: 0.9957
# Epoch 33/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0127 - sparse_categorical_accuracy: 0.9961Epoch 00032: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0132 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.0124 - val_sparse_categorical_accuracy: 0.9957
# Epoch 34/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0113 - sparse_categorical_accuracy: 0.9960Epoch 00033: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0114 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.0138 - val_sparse_categorical_accuracy: 0.9950
# Epoch 35/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0147 - sparse_categorical_accuracy: 0.9947Epoch 00034: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0146 - sparse_categorical_accuracy: 0.9947 - val_loss: 0.0132 - val_sparse_categorical_accuracy: 0.9954
# Epoch 36/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0117 - sparse_categorical_accuracy: 0.9954Epoch 00035: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0116 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.0143 - val_sparse_categorical_accuracy: 0.9954
# Epoch 37/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0137 - sparse_categorical_accuracy: 0.9959Epoch 00036: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0136 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.0127 - val_sparse_categorical_accuracy: 0.9954
# Epoch 38/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0142 - sparse_categorical_accuracy: 0.9955Epoch 00037: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0142 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.0124 - val_sparse_categorical_accuracy: 0.9961
# Epoch 39/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0119 - sparse_categorical_accuracy: 0.9956Epoch 00038: val_loss did not improve
# 11231/11231 [==============================] - 36s - loss: 0.0119 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.0130 - val_sparse_categorical_accuracy: 0.9950
# Epoch 40/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0144 - sparse_categorical_accuracy: 0.9956Epoch 00039: val_loss improved from 0.01151 to 0.01034, saving model to model11.h5
# 11231/11231 [==============================] - 36s - loss: 0.0143 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.0103 - val_sparse_categorical_accuracy: 0.9964
# Epoch 41/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0136 - sparse_categorical_accuracy: 0.9956Epoch 00040: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0135 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.0125 - val_sparse_categorical_accuracy: 0.9961
# Epoch 42/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0113 - sparse_categorical_accuracy: 0.9968Epoch 00041: val_loss did not improve
# 11231/11231 [==============================] - 36s - loss: 0.0113 - sparse_categorical_accuracy: 0.9968 - val_loss: 0.0109 - val_sparse_categorical_accuracy: 0.9954
# Epoch 43/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0146 - sparse_categorical_accuracy: 0.9952Epoch 00042: val_loss did not improve
# 11231/11231 [==============================] - 36s - loss: 0.0149 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.0126 - val_sparse_categorical_accuracy: 0.9972
# Epoch 44/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0110 - sparse_categorical_accuracy: 0.9961Epoch 00043: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0109 - sparse_categorical_accuracy: 0.9961 - val_loss: 0.0130 - val_sparse_categorical_accuracy: 0.9950
# Epoch 45/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0074 - sparse_categorical_accuracy: 0.9973Epoch 00044: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0074 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0128 - val_sparse_categorical_accuracy: 0.9961
# Epoch 46/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0110 - sparse_categorical_accuracy: 0.9969Epoch 00045: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0109 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.0142 - val_sparse_categorical_accuracy: 0.9961
# Epoch 47/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0107 - sparse_categorical_accuracy: 0.9958Epoch 00046: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0107 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.0122 - val_sparse_categorical_accuracy: 0.9961
# Epoch 48/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0121 - sparse_categorical_accuracy: 0.9959Epoch 00047: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0120 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.0141 - val_sparse_categorical_accuracy: 0.9961
# Epoch 49/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0125 - sparse_categorical_accuracy: 0.9955Epoch 00048: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0127 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.0126 - val_sparse_categorical_accuracy: 0.9957
# Epoch 50/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0097 - sparse_categorical_accuracy: 0.9965Epoch 00049: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0097 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.0134 - val_sparse_categorical_accuracy: 0.9957
# Epoch 51/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0094 - sparse_categorical_accuracy: 0.9965Epoch 00050: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0094 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.0119 - val_sparse_categorical_accuracy: 0.9964
# Epoch 52/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0087 - sparse_categorical_accuracy: 0.9965Epoch 00051: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0087 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.0111 - val_sparse_categorical_accuracy: 0.9968
# Epoch 53/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0136 - sparse_categorical_accuracy: 0.9958Epoch 00052: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0136 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.0112 - val_sparse_categorical_accuracy: 0.9964
# Epoch 54/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0086 - sparse_categorical_accuracy: 0.9964Epoch 00053: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0086 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0128 - val_sparse_categorical_accuracy: 0.9957
# Epoch 55/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0090 - sparse_categorical_accuracy: 0.9971Epoch 00054: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0092 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0117 - val_sparse_categorical_accuracy: 0.9964
# Epoch 56/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0091 - sparse_categorical_accuracy: 0.9968Epoch 00055: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0096 - sparse_categorical_accuracy: 0.9966 - val_loss: 0.0116 - val_sparse_categorical_accuracy: 0.9961
# Epoch 57/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0106 - sparse_categorical_accuracy: 0.9963Epoch 00056: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0106 - sparse_categorical_accuracy: 0.9963 - val_loss: 0.0123 - val_sparse_categorical_accuracy: 0.9954
# Epoch 58/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0088 - sparse_categorical_accuracy: 0.9973Epoch 00057: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0088 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0276 - val_sparse_categorical_accuracy: 0.9929
# Epoch 59/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0083 - sparse_categorical_accuracy: 0.9970Epoch 00058: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0083 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0116 - val_sparse_categorical_accuracy: 0.9964
# Epoch 60/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0102 - sparse_categorical_accuracy: 0.9971Epoch 00059: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0102 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0166 - val_sparse_categorical_accuracy: 0.9947
# Epoch 61/1000
# 11200/11231 [============================>.] - ETA: 0s - loss: 0.0109 - sparse_categorical_accuracy: 0.9963Epoch 00060: val_loss did not improve
# 11231/11231 [==============================] - 35s - loss: 0.0109 - sparse_categorical_accuracy: 0.9963 - val_loss: 0.0118 - val_sparse_categorical_accuracy: 0.9964
# Epoch 00060: early stopping

# %%
from keras.models import load_model
trained_model = load_model(model_name)
print(trained_model.metrics_names)
trained_model.evaluate(x=X_train, y=y_train)
# Out:
# ['loss', 'sparse_categorical_accuracy']
# 11231/11231 [==============================] - 15s
# [0.0039077443620986795, 0.99875345027156981]

# %%
trained_model.evaluate(x=X_val, y=y_val)
# Out:
# 2784/2809 [============================>.] - ETA: 0s
# [0.010337617953393757, 0.99644001423994299]
