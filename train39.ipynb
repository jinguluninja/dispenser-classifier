# %%
import os
import keras
import numpy as np
np.random.seed(135109)
# Out:
# Using TensorFlow backend.

# %%
sensor = '39'

# %%
def dataset():
    X = []
    y = []
    data_dir_0 = sorted(os.listdir(os.path.join('pac_data', sensor, '0')))   
    i = 0
    for f in data_dir_0:
        if i % 100 == 0: print(i)
        i += 1
        X.append(np.load(os.path.join('pac_data', sensor, '0', f))['x'])
        y.append(0)
    X = np.asarray(X, dtype=np.float16)
    y = np.asarray(y, dtype=int)
    indices = np.arange(y.shape[0])
    np.random.shuffle(indices)
    X_train = X[indices[:int(0.8*len(indices))]]
    y_train = y[indices[:int(0.8*len(indices))]]
    X_val = X[indices[int(0.8*len(indices)):]]
    y_val = y[indices[int(0.8*len(indices)):]]
    labels_present = os.listdir(os.path.join('pac_data', sensor))
    if '1' in labels_present:
        X = []
        y = []
        data_dir_1 = sorted(os.listdir(os.path.join('pac_data', sensor, '1')))
        i = 0
        for f in data_dir_1:
            if i % 100 == 0: print(i)
            i += 1
            X.append(np.load(os.path.join('pac_data', sensor, '1', f))['x'])
            y.append(1)        
        X = np.asarray(X, dtype=np.float16)
        y = np.asarray(y, dtype=int)
        indices = np.arange(y.shape[0])
        np.random.shuffle(indices)
        X_train = np.concatenate([X_train, X[indices[:int(0.8*len(indices))]]])
        y_train = np.concatenate([y_train, y[indices[:int(0.8*len(indices))]]])
        X_val = np.concatenate([X_val, X[indices[int(0.8*len(indices)):]]])
        y_val = np.concatenate([y_val, y[indices[int(0.8*len(indices)):]]])
    X_train = np.expand_dims(np.asarray(X_train, dtype=np.float16), axis=3)
    y_train = np.asarray(y_train, dtype=int)
    X_val = np.expand_dims(np.asarray(X_val, dtype=np.float16), axis=3)
    y_val = np.asarray(y_val, dtype=int)
    X_train /= 5.
    X_val /= 5.
    mean_arr = np.mean(X_train, axis = 0)
    np.save(os.path.join('pac_data', sensor, 'mean.npy'), mean_arr)
    X_train -= mean_arr 
    X_val -= mean_arr  
    return X_train, y_train, X_val, y_val

# %%
X_train, y_train, X_val, y_val = dataset()
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 0

# %%
print(X_train.shape, y_train.shape, X_val.shape, y_val.shape)
# Out:
# (6068, 240, 320, 1) (6068,) (1518, 240, 320, 1) (1518,)

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/gpu:0']

# %%
from keras.models import Sequential
from keras.layers import TimeDistributed, GlobalAveragePooling2D, Activation, Dense, Input
from keras.layers import BatchNormalization, Conv2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D
from keras.layers import GlobalMaxPooling2D
from keras.layers.recurrent import LSTM
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras.layers import Dropout, Flatten
from keras.layers import concatenate
from keras import regularizers
from keras import initializers
from keras import constraints
from keras.models import Model
from keras import backend as K
from keras.utils.layer_utils import convert_all_kernels_in_model
from keras.utils.data_utils import get_file
from keras.utils import conv_utils
from keras.engine.topology import get_source_inputs
from keras.engine import InputSpec
from keras.applications.xception import Xception
from keras import metrics

# %%
#linear
def linear(dropout):
    inputs = Input(shape=(240, 320, 1))
    x = Flatten()(inputs)
    x = Dropout(dropout)(x)
    x = Dense(2, activation='softmax')(x)
    model = Model(inputs, x, name='linear')
    return model

# %%
from keras import layers
from keras.layers import Activation
from keras.layers import SeparableConv2D

def xception(dropout):
    inputs = Input(shape=(240, 320, 1))    

    x = Conv2D(32, (3, 3), padding='same', strides=(2, 2), use_bias=False, name='block1_conv1')(inputs)
    x = BatchNormalization(name='block1_conv1_bn')(x)
    x = Activation('relu', name='block1_conv1_act')(x)
    x = Conv2D(64, (3, 3), padding='same', use_bias=False, name='block1_conv2')(x)
    x = BatchNormalization(name='block1_conv2_bn')(x)
    x = Activation('relu', name='block1_conv2_act')(x)

    residual = Conv2D(128, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, name='block2_sepconv1')(x)
    x = BatchNormalization(name='block2_sepconv1_bn')(x)
    x = Activation('relu', name='block2_sepconv2_act')(x)
    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, name='block2_sepconv2')(x)
    x = BatchNormalization(name='block2_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block2_pool')(x)
    x = layers.add([x, residual])

    residual = Conv2D(256, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block3_sepconv1_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, name='block3_sepconv1')(x)
    x = BatchNormalization(name='block3_sepconv1_bn')(x)
    x = Activation('relu', name='block3_sepconv2_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, name='block3_sepconv2')(x)
    x = BatchNormalization(name='block3_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block3_pool')(x)
    x = layers.add([x, residual])

    residual = Conv2D(728, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block4_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name='block4_sepconv1')(x)
    x = BatchNormalization(name='block4_sepconv1_bn')(x)
    x = Activation('relu', name='block4_sepconv2_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name='block4_sepconv2')(x)
    x = BatchNormalization(name='block4_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block4_pool')(x)
    x = layers.add([x, residual])

    for i in range(8):
        residual = x
        prefix = 'block' + str(i + 5)

        x = Activation('relu', name=prefix + '_sepconv1_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name=prefix + '_sepconv1')(x)
        x = BatchNormalization(name=prefix + '_sepconv1_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv2_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name=prefix + '_sepconv2')(x)
        x = BatchNormalization(name=prefix + '_sepconv2_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv3_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name=prefix + '_sepconv3')(x)
        x = BatchNormalization(name=prefix + '_sepconv3_bn')(x)

        x = layers.add([x, residual])

    residual = Conv2D(1024, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block13_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name='block13_sepconv1')(x)
    x = BatchNormalization(name='block13_sepconv1_bn')(x)
    x = Activation('relu', name='block13_sepconv2_act')(x)
    x = SeparableConv2D(1024, (3, 3), padding='same', use_bias=False, name='block13_sepconv2')(x)
    x = BatchNormalization(name='block13_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block13_pool')(x)
    x = layers.add([x, residual])

    x = SeparableConv2D(1536, (3, 3), padding='same', use_bias=False, name='block14_sepconv1')(x)
    x = BatchNormalization(name='block14_sepconv1_bn')(x)
    x = Activation('relu', name='block14_sepconv1_act')(x)

    x = SeparableConv2D(2048, (3, 3), padding='same', use_bias=False, name='block14_sepconv2')(x)
    x = BatchNormalization(name='block14_sepconv2_bn')(x)
    x = Activation('relu', name='block14_sepconv2_act')(x)

    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dropout(dropout)(x)
    x = Dense(2, activation='softmax', name='predictions')(x)
    model = Model(inputs, x, name='xception')
    return model


'''
def xception(dropout):
    base_model = Xception(include_top=False, input_shape = (240, 320, 1), pooling='avg')
    x = base_model.output
    x = Flatten()(x)
    x = Dropout(dropout)(x) # drop prob
    predictions = Dense(2, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions, name='linear')
    return model
'''
# Out:
# "\ndef xception(dropout):\n    base_model = Xception(include_top=False, input_shape = (240, 320, 1), pooling='avg')\n    x = base_model.output\n    x = Flatten()(x)\n    x = Dropout(dropout)(x) # drop prob\n    predictions = Dense(2, activation='softmax')(x)\n    model = Model(inputs=base_model.input, outputs=predictions, name='linear')\n    return model\n"

# %%
def vanillacnn(dropout):
    inputs = Input(shape=(240, 320, 1)) 
    x = Conv2D(32, (3, 3), strides=(2, 2), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = Dropout(dropout)(x)
    
    x = Conv2D(64, (3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = Dropout(dropout)(x)
    
    x = Conv2D(128, (3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = Dropout(dropout)(x)
    
    x = Conv2D(256, (3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    
    x = Flatten()(x)
    x = Dropout(dropout)(x)
    x = Dense(2, activation='softmax', name='predictions')(x)
    model = Model(inputs, x, name='xception')
    return model

# %%
model_name = 'model' + sensor + '.h5'
model = vanillacnn(0.5)

adam = keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=[metrics.sparse_categorical_accuracy])


checkpoint = ModelCheckpoint(model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
stop = EarlyStopping(patience=20, verbose=1)

callbacks_list = [checkpoint, stop]

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 240, 320, 1)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 120, 160, 32)      320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 120, 160, 32)      128
# _________________________________________________________________
# activation_1 (Activation)    (None, 120, 160, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 60, 80, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60, 80, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 40, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 30, 40, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 40, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 15, 20, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 15, 20, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 10, 128)        73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 10, 128)        512
# _________________________________________________________________
# activation_3 (Activation)    (None, 8, 10, 128)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 5, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 5, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 3, 256)         295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2, 3, 256)         1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 2, 3, 256)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 2, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# predictions (Dense)          (None, 2)                 1026
# =================================================================
# Total params: 390,786
# Trainable params: 389,826
# Non-trainable params: 960
# _________________________________________________________________

# %%
model.fit(x=X_train, 
          y=y_train, 
          batch_size=32, 
          epochs=1000, 
          verbose=1, 
          callbacks=callbacks_list, 
          validation_data=(X_val, y_val), 
          shuffle=True)
# Out:
# Train on 6068 samples, validate on 1518 samples
# Epoch 1/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.1167 - sparse_categorical_accuracy: 0.9858Epoch 00000: val_loss improved from inf to 1.40779, saving model to model39.h5
# 6068/6068 [==============================] - 20s - loss: 0.1163 - sparse_categorical_accuracy: 0.9858 - val_loss: 1.4078 - val_sparse_categorical_accuracy: 0.0086
# Epoch 2/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0437 - sparse_categorical_accuracy: 0.9901Epoch 00001: val_loss improved from 1.40779 to 0.61141, saving model to model39.h5
# 6068/6068 [==============================] - 19s - loss: 0.0436 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.6114 - val_sparse_categorical_accuracy: 0.9341
# Epoch 3/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0368 - sparse_categorical_accuracy: 0.9902Epoch 00002: val_loss improved from 0.61141 to 0.09565, saving model to model39.h5
# 6068/6068 [==============================] - 19s - loss: 0.0367 - sparse_categorical_accuracy: 0.9903 - val_loss: 0.0957 - val_sparse_categorical_accuracy: 0.9908
# Epoch 4/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0331 - sparse_categorical_accuracy: 0.9912Epoch 00003: val_loss improved from 0.09565 to 0.02825, saving model to model39.h5
# 6068/6068 [==============================] - 19s - loss: 0.0330 - sparse_categorical_accuracy: 0.9913 - val_loss: 0.0283 - val_sparse_categorical_accuracy: 0.9914
# Epoch 5/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0325 - sparse_categorical_accuracy: 0.9907Epoch 00004: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0324 - sparse_categorical_accuracy: 0.9908 - val_loss: 0.0360 - val_sparse_categorical_accuracy: 0.9914
# Epoch 6/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0300 - sparse_categorical_accuracy: 0.9912Epoch 00005: val_loss improved from 0.02825 to 0.02553, saving model to model39.h5
# 6068/6068 [==============================] - 19s - loss: 0.0300 - sparse_categorical_accuracy: 0.9913 - val_loss: 0.0255 - val_sparse_categorical_accuracy: 0.9928
# Epoch 7/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0294 - sparse_categorical_accuracy: 0.9909Epoch 00006: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0293 - sparse_categorical_accuracy: 0.9909 - val_loss: 0.0336 - val_sparse_categorical_accuracy: 0.9921
# Epoch 8/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0250 - sparse_categorical_accuracy: 0.9926Epoch 00007: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0249 - sparse_categorical_accuracy: 0.9926 - val_loss: 0.0318 - val_sparse_categorical_accuracy: 0.9895
# Epoch 9/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0225 - sparse_categorical_accuracy: 0.9924Epoch 00008: val_loss improved from 0.02553 to 0.02257, saving model to model39.h5
# 6068/6068 [==============================] - 19s - loss: 0.0224 - sparse_categorical_accuracy: 0.9924 - val_loss: 0.0226 - val_sparse_categorical_accuracy: 0.9934
# Epoch 10/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0221 - sparse_categorical_accuracy: 0.9919Epoch 00009: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0220 - sparse_categorical_accuracy: 0.9919 - val_loss: 0.0289 - val_sparse_categorical_accuracy: 0.9914
# Epoch 11/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0207 - sparse_categorical_accuracy: 0.9929Epoch 00010: val_loss improved from 0.02257 to 0.02228, saving model to model39.h5
# 6068/6068 [==============================] - 19s - loss: 0.0207 - sparse_categorical_accuracy: 0.9929 - val_loss: 0.0223 - val_sparse_categorical_accuracy: 0.9941
# Epoch 12/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0192 - sparse_categorical_accuracy: 0.9934Epoch 00011: val_loss improved from 0.02228 to 0.01905, saving model to model39.h5
# 6068/6068 [==============================] - 19s - loss: 0.0191 - sparse_categorical_accuracy: 0.9934 - val_loss: 0.0191 - val_sparse_categorical_accuracy: 0.9947
# Epoch 13/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0204 - sparse_categorical_accuracy: 0.9929Epoch 00012: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0203 - sparse_categorical_accuracy: 0.9929 - val_loss: 0.0318 - val_sparse_categorical_accuracy: 0.9875
# Epoch 14/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0140 - sparse_categorical_accuracy: 0.9952Epoch 00013: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0140 - sparse_categorical_accuracy: 0.9952 - val_loss: 0.0197 - val_sparse_categorical_accuracy: 0.9928
# Epoch 15/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0134 - sparse_categorical_accuracy: 0.9940Epoch 00014: val_loss improved from 0.01905 to 0.01800, saving model to model39.h5
# 6068/6068 [==============================] - 19s - loss: 0.0134 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.0180 - val_sparse_categorical_accuracy: 0.9954
# Epoch 16/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0170 - sparse_categorical_accuracy: 0.9954Epoch 00015: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0170 - sparse_categorical_accuracy: 0.9954 - val_loss: 0.0199 - val_sparse_categorical_accuracy: 0.9928
# Epoch 17/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0119 - sparse_categorical_accuracy: 0.9959Epoch 00016: val_loss improved from 0.01800 to 0.01773, saving model to model39.h5
# 6068/6068 [==============================] - 19s - loss: 0.0119 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.0177 - val_sparse_categorical_accuracy: 0.9934
# Epoch 18/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0101 - sparse_categorical_accuracy: 0.9962Epoch 00017: val_loss improved from 0.01773 to 0.01660, saving model to model39.h5
# 6068/6068 [==============================] - 19s - loss: 0.0101 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0166 - val_sparse_categorical_accuracy: 0.9941
# Epoch 19/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0123 - sparse_categorical_accuracy: 0.9965Epoch 00018: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0122 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.0378 - val_sparse_categorical_accuracy: 0.9895
# Epoch 20/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0109 - sparse_categorical_accuracy: 0.9962Epoch 00019: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0108 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0660 - val_sparse_categorical_accuracy: 0.9862
# Epoch 21/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0136 - sparse_categorical_accuracy: 0.9955Epoch 00020: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0136 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.0174 - val_sparse_categorical_accuracy: 0.9928
# Epoch 22/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0085 - sparse_categorical_accuracy: 0.9969Epoch 00021: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0085 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.0201 - val_sparse_categorical_accuracy: 0.9941
# Epoch 23/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0099 - sparse_categorical_accuracy: 0.9964Epoch 00022: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0099 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0178 - val_sparse_categorical_accuracy: 0.9947
# Epoch 24/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0119 - sparse_categorical_accuracy: 0.9959Epoch 00023: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0119 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.0193 - val_sparse_categorical_accuracy: 0.9947
# Epoch 25/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0096 - sparse_categorical_accuracy: 0.9964Epoch 00024: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0096 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0180 - val_sparse_categorical_accuracy: 0.9947
# Epoch 26/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0141 - sparse_categorical_accuracy: 0.9954Epoch 00025: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0140 - sparse_categorical_accuracy: 0.9954 - val_loss: 0.0173 - val_sparse_categorical_accuracy: 0.9954
# Epoch 27/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0097 - sparse_categorical_accuracy: 0.9972Epoch 00026: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0103 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0203 - val_sparse_categorical_accuracy: 0.9928
# Epoch 28/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0093 - sparse_categorical_accuracy: 0.9970Epoch 00027: val_loss improved from 0.01660 to 0.01657, saving model to model39.h5
# 6068/6068 [==============================] - 19s - loss: 0.0093 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0166 - val_sparse_categorical_accuracy: 0.9947
# Epoch 29/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0089 - sparse_categorical_accuracy: 0.9974Epoch 00028: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0088 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.0232 - val_sparse_categorical_accuracy: 0.9947
# Epoch 30/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0088 - sparse_categorical_accuracy: 0.9967Epoch 00029: val_loss improved from 0.01657 to 0.01629, saving model to model39.h5
# 6068/6068 [==============================] - 19s - loss: 0.0088 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.0163 - val_sparse_categorical_accuracy: 0.9954
# Epoch 31/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0078 - sparse_categorical_accuracy: 0.9972Epoch 00030: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0078 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0201 - val_sparse_categorical_accuracy: 0.9954
# Epoch 32/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0107 - sparse_categorical_accuracy: 0.9977Epoch 00031: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0107 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0232 - val_sparse_categorical_accuracy: 0.9941
# Epoch 33/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0065 - sparse_categorical_accuracy: 0.9980Epoch 00032: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0065 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0194 - val_sparse_categorical_accuracy: 0.9941
# Epoch 34/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0064 - sparse_categorical_accuracy: 0.9980Epoch 00033: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0064 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0172 - val_sparse_categorical_accuracy: 0.9954
# Epoch 35/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0052 - sparse_categorical_accuracy: 0.9983Epoch 00034: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0052 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0192 - val_sparse_categorical_accuracy: 0.9941
# Epoch 36/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0058 - sparse_categorical_accuracy: 0.9975Epoch 00035: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0058 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0247 - val_sparse_categorical_accuracy: 0.9941
# Epoch 37/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0050 - sparse_categorical_accuracy: 0.9985Epoch 00036: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0049 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0196 - val_sparse_categorical_accuracy: 0.9928
# Epoch 38/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0096 - sparse_categorical_accuracy: 0.9964Epoch 00037: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0096 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0249 - val_sparse_categorical_accuracy: 0.9947
# Epoch 39/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0068 - sparse_categorical_accuracy: 0.9975Epoch 00038: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0067 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0167 - val_sparse_categorical_accuracy: 0.9947
# Epoch 40/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0073 - sparse_categorical_accuracy: 0.9969Epoch 00039: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0072 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.0183 - val_sparse_categorical_accuracy: 0.9954
# Epoch 41/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0046 - sparse_categorical_accuracy: 0.9990Epoch 00040: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0047 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0179 - val_sparse_categorical_accuracy: 0.9954
# Epoch 42/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0053 - sparse_categorical_accuracy: 0.9980Epoch 00041: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0053 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0228 - val_sparse_categorical_accuracy: 0.9941
# Epoch 43/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0049 - sparse_categorical_accuracy: 0.9985Epoch 00042: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0049 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0181 - val_sparse_categorical_accuracy: 0.9941
# Epoch 44/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0089 - sparse_categorical_accuracy: 0.9972Epoch 00043: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0089 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0220 - val_sparse_categorical_accuracy: 0.9947
# Epoch 45/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0060 - sparse_categorical_accuracy: 0.9977Epoch 00044: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0060 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0235 - val_sparse_categorical_accuracy: 0.9941
# Epoch 46/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0044 - sparse_categorical_accuracy: 0.9988Epoch 00045: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0044 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0178 - val_sparse_categorical_accuracy: 0.9960
# Epoch 47/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0069 - sparse_categorical_accuracy: 0.9987Epoch 00046: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0068 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0412 - val_sparse_categorical_accuracy: 0.9868
# Epoch 48/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0047 - sparse_categorical_accuracy: 0.9987Epoch 00047: val_loss improved from 0.01629 to 0.01563, saving model to model39.h5
# 6068/6068 [==============================] - 19s - loss: 0.0047 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0156 - val_sparse_categorical_accuracy: 0.9954
# Epoch 49/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0037 - sparse_categorical_accuracy: 0.9985Epoch 00048: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0037 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0208 - val_sparse_categorical_accuracy: 0.9954
# Epoch 50/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0040 - sparse_categorical_accuracy: 0.9985Epoch 00049: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0040 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0260 - val_sparse_categorical_accuracy: 0.9947
# Epoch 51/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0065 - sparse_categorical_accuracy: 0.9982Epoch 00050: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0065 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0187 - val_sparse_categorical_accuracy: 0.9954
# Epoch 52/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0049 - sparse_categorical_accuracy: 0.9980Epoch 00051: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0049 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0166 - val_sparse_categorical_accuracy: 0.9967
# Epoch 53/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0064 - sparse_categorical_accuracy: 0.9980Epoch 00052: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0064 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0168 - val_sparse_categorical_accuracy: 0.9960
# Epoch 54/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0070 - sparse_categorical_accuracy: 0.9979Epoch 00053: val_loss improved from 0.01563 to 0.01535, saving model to model39.h5
# 6068/6068 [==============================] - 19s - loss: 0.0069 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0154 - val_sparse_categorical_accuracy: 0.9960
# Epoch 55/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0049 - sparse_categorical_accuracy: 0.9985Epoch 00054: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0049 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0285 - val_sparse_categorical_accuracy: 0.9947
# Epoch 56/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0029 - sparse_categorical_accuracy: 0.9993Epoch 00055: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0029 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.0204 - val_sparse_categorical_accuracy: 0.9954
# Epoch 57/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0032 - sparse_categorical_accuracy: 0.9988Epoch 00056: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0031 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0179 - val_sparse_categorical_accuracy: 0.9960
# Epoch 58/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0052 - sparse_categorical_accuracy: 0.9987Epoch 00057: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0052 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0159 - val_sparse_categorical_accuracy: 0.9960
# Epoch 59/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0027 - sparse_categorical_accuracy: 0.9988Epoch 00058: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0027 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0193 - val_sparse_categorical_accuracy: 0.9967
# Epoch 60/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0044 - sparse_categorical_accuracy: 0.9987Epoch 00059: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0044 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0201 - val_sparse_categorical_accuracy: 0.9954
# Epoch 61/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0039 - sparse_categorical_accuracy: 0.9987Epoch 00060: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0039 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0163 - val_sparse_categorical_accuracy: 0.9967
# Epoch 62/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0078 - sparse_categorical_accuracy: 0.9979Epoch 00061: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0078 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0285 - val_sparse_categorical_accuracy: 0.9954
# Epoch 63/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0056 - sparse_categorical_accuracy: 0.9985Epoch 00062: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0055 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0232 - val_sparse_categorical_accuracy: 0.9960
# Epoch 64/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0035 - sparse_categorical_accuracy: 0.9983Epoch 00063: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0035 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0173 - val_sparse_categorical_accuracy: 0.9960
# Epoch 65/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0052 - sparse_categorical_accuracy: 0.9988Epoch 00064: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0052 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0228 - val_sparse_categorical_accuracy: 0.9954
# Epoch 66/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0041 - sparse_categorical_accuracy: 0.9990Epoch 00065: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0040 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0282 - val_sparse_categorical_accuracy: 0.9914
# Epoch 67/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0036 - sparse_categorical_accuracy: 0.9988Epoch 00066: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0036 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0200 - val_sparse_categorical_accuracy: 0.9954
# Epoch 68/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0039 - sparse_categorical_accuracy: 0.9987Epoch 00067: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0039 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0236 - val_sparse_categorical_accuracy: 0.9928
# Epoch 69/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0047 - sparse_categorical_accuracy: 0.9990Epoch 00068: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0047 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0161 - val_sparse_categorical_accuracy: 0.9960
# Epoch 70/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0021 - sparse_categorical_accuracy: 0.9993Epoch 00069: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0021 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.0171 - val_sparse_categorical_accuracy: 0.9954
# Epoch 71/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0039 - sparse_categorical_accuracy: 0.9988Epoch 00070: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0041 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0199 - val_sparse_categorical_accuracy: 0.9967
# Epoch 72/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0011 - sparse_categorical_accuracy: 0.9997Epoch 00071: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0011 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.0157 - val_sparse_categorical_accuracy: 0.9967
# Epoch 73/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0019 - sparse_categorical_accuracy: 0.9992Epoch 00072: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0019 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.0189 - val_sparse_categorical_accuracy: 0.9967
# Epoch 74/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0049 - sparse_categorical_accuracy: 0.9987Epoch 00073: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0049 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0158 - val_sparse_categorical_accuracy: 0.9967
# Epoch 75/1000
# 6048/6068 [============================>.] - ETA: 0s - loss: 0.0038 - sparse_categorical_accuracy: 0.9990Epoch 00074: val_loss did not improve
# 6068/6068 [==============================] - 19s - loss: 0.0038 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0197 - val_sparse_categorical_accuracy: 0.9960
# Epoch 00074: early stopping

# %%
from keras.models import load_model
trained_model = load_model(model_name)
print(trained_model.metrics_names)
trained_model.evaluate(x=X_train, y=y_train)
# Out:
# ['loss', 'sparse_categorical_accuracy']
# 6048/6068 [============================>.] - ETA: 0s
# [0.00079641467331427939, 1.0]

# %%
trained_model.evaluate(x=X_val, y=y_val)
# Out:
# 1504/1518 [============================>.] - ETA: 0s
# [0.015353943897062749, 0.99604743098710047]
