# %%
import os
import keras
import numpy as np
np.random.seed(135109)
# Out:
# Using TensorFlow backend.

# %%
sensor = '23'

# %%
def dataset():
    X = []
    y = []
    data_dir_0 = sorted(os.listdir(os.path.join('pac_data', sensor, '0')))   
    i = 0
    for f in data_dir_0:
        if i % 100 == 0: print(i)
        i += 1
        X.append(np.load(os.path.join('pac_data', sensor, '0', f))['x'])
        y.append(0)
    X = np.asarray(X, dtype=np.float16)
    y = np.asarray(y, dtype=int)
    indices = np.arange(y.shape[0])
    np.random.shuffle(indices)
    X_train = X[indices[:int(0.8*len(indices))]]
    y_train = y[indices[:int(0.8*len(indices))]]
    X_val = X[indices[int(0.8*len(indices)):]]
    y_val = y[indices[int(0.8*len(indices)):]]
    labels_present = os.listdir(os.path.join('pac_data', sensor))
    if '1' in labels_present:
        X = []
        y = []
        data_dir_1 = sorted(os.listdir(os.path.join('pac_data', sensor, '1')))
        i = 0
        for f in data_dir_1:
            if i % 100 == 0: print(i)
            i += 1
            X.append(np.load(os.path.join('pac_data', sensor, '1', f))['x'])
            y.append(1)        
        X = np.asarray(X, dtype=np.float16)
        y = np.asarray(y, dtype=int)
        indices = np.arange(y.shape[0])
        np.random.shuffle(indices)
        X_train = np.concatenate([X_train, X[indices[:int(0.8*len(indices))]]])
        y_train = np.concatenate([y_train, y[indices[:int(0.8*len(indices))]]])
        X_val = np.concatenate([X_val, X[indices[int(0.8*len(indices)):]]])
        y_val = np.concatenate([y_val, y[indices[int(0.8*len(indices)):]]])
    X_train = np.expand_dims(np.asarray(X_train, dtype=np.float16), axis=3)
    y_train = np.asarray(y_train, dtype=int)
    X_val = np.expand_dims(np.asarray(X_val, dtype=np.float16), axis=3)
    y_val = np.asarray(y_val, dtype=int)
    X_train /= 5.
    X_val /= 5.
    mean_arr = np.mean(X_train, axis = 0)
    np.save(os.path.join('pac_data', sensor, 'mean.npy'), mean_arr)
    X_train -= mean_arr 
    X_val -= mean_arr  
    return X_train, y_train, X_val, y_val

# %%
X_train, y_train, X_val, y_val = dataset()
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800

# %%
print(X_train.shape, y_train.shape, X_val.shape, y_val.shape)
# Out:
# (2799, 240, 320, 1) (2799,) (700, 240, 320, 1) (700,)

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/gpu:0']

# %%
from keras.models import Sequential
from keras.layers import TimeDistributed, GlobalAveragePooling2D, Activation, Dense, Input
from keras.layers import BatchNormalization, Conv2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D
from keras.layers import GlobalMaxPooling2D
from keras.layers.recurrent import LSTM
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras.layers import Dropout, Flatten
from keras.layers import concatenate
from keras import regularizers
from keras import initializers
from keras import constraints
from keras.models import Model
from keras import backend as K
from keras.utils.layer_utils import convert_all_kernels_in_model
from keras.utils.data_utils import get_file
from keras.utils import conv_utils
from keras.engine.topology import get_source_inputs
from keras.engine import InputSpec
from keras.applications.xception import Xception
from keras import metrics

# %%
#linear
def linear(dropout):
    inputs = Input(shape=(240, 320, 1))
    x = Flatten()(inputs)
    x = Dropout(dropout)(x)
    x = Dense(2, activation='softmax')(x)
    model = Model(inputs, x, name='linear')
    return model

# %%
from keras import layers
from keras.layers import Activation
from keras.layers import SeparableConv2D

def xception(dropout):
    inputs = Input(shape=(240, 320, 1))    

    x = Conv2D(32, (3, 3), padding='same', strides=(2, 2), use_bias=False, name='block1_conv1')(inputs)
    x = BatchNormalization(name='block1_conv1_bn')(x)
    x = Activation('relu', name='block1_conv1_act')(x)
    x = Conv2D(64, (3, 3), padding='same', use_bias=False, name='block1_conv2')(x)
    x = BatchNormalization(name='block1_conv2_bn')(x)
    x = Activation('relu', name='block1_conv2_act')(x)

    residual = Conv2D(128, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, name='block2_sepconv1')(x)
    x = BatchNormalization(name='block2_sepconv1_bn')(x)
    x = Activation('relu', name='block2_sepconv2_act')(x)
    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, name='block2_sepconv2')(x)
    x = BatchNormalization(name='block2_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block2_pool')(x)
    x = layers.add([x, residual])

    residual = Conv2D(256, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block3_sepconv1_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, name='block3_sepconv1')(x)
    x = BatchNormalization(name='block3_sepconv1_bn')(x)
    x = Activation('relu', name='block3_sepconv2_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, name='block3_sepconv2')(x)
    x = BatchNormalization(name='block3_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block3_pool')(x)
    x = layers.add([x, residual])

    residual = Conv2D(728, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block4_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name='block4_sepconv1')(x)
    x = BatchNormalization(name='block4_sepconv1_bn')(x)
    x = Activation('relu', name='block4_sepconv2_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name='block4_sepconv2')(x)
    x = BatchNormalization(name='block4_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block4_pool')(x)
    x = layers.add([x, residual])

    for i in range(8):
        residual = x
        prefix = 'block' + str(i + 5)

        x = Activation('relu', name=prefix + '_sepconv1_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name=prefix + '_sepconv1')(x)
        x = BatchNormalization(name=prefix + '_sepconv1_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv2_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name=prefix + '_sepconv2')(x)
        x = BatchNormalization(name=prefix + '_sepconv2_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv3_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name=prefix + '_sepconv3')(x)
        x = BatchNormalization(name=prefix + '_sepconv3_bn')(x)

        x = layers.add([x, residual])

    residual = Conv2D(1024, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block13_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name='block13_sepconv1')(x)
    x = BatchNormalization(name='block13_sepconv1_bn')(x)
    x = Activation('relu', name='block13_sepconv2_act')(x)
    x = SeparableConv2D(1024, (3, 3), padding='same', use_bias=False, name='block13_sepconv2')(x)
    x = BatchNormalization(name='block13_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block13_pool')(x)
    x = layers.add([x, residual])

    x = SeparableConv2D(1536, (3, 3), padding='same', use_bias=False, name='block14_sepconv1')(x)
    x = BatchNormalization(name='block14_sepconv1_bn')(x)
    x = Activation('relu', name='block14_sepconv1_act')(x)

    x = SeparableConv2D(2048, (3, 3), padding='same', use_bias=False, name='block14_sepconv2')(x)
    x = BatchNormalization(name='block14_sepconv2_bn')(x)
    x = Activation('relu', name='block14_sepconv2_act')(x)

    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dropout(dropout)(x)
    x = Dense(2, activation='softmax', name='predictions')(x)
    model = Model(inputs, x, name='xception')
    return model


'''
def xception(dropout):
    base_model = Xception(include_top=False, input_shape = (240, 320, 1), pooling='avg')
    x = base_model.output
    x = Flatten()(x)
    x = Dropout(dropout)(x) # drop prob
    predictions = Dense(2, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions, name='linear')
    return model
'''
# Out:
# "\ndef xception(dropout):\n    base_model = Xception(include_top=False, input_shape = (240, 320, 1), pooling='avg')\n    x = base_model.output\n    x = Flatten()(x)\n    x = Dropout(dropout)(x) # drop prob\n    predictions = Dense(2, activation='softmax')(x)\n    model = Model(inputs=base_model.input, outputs=predictions, name='linear')\n    return model\n"

# %%
def vanillacnn(dropout):
    inputs = Input(shape=(240, 320, 1)) 
    x = Conv2D(32, (3, 3), strides=(2, 2), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = Dropout(dropout)(x)
    
    x = Conv2D(64, (3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = Dropout(dropout)(x)
    
    x = Conv2D(128, (3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = Dropout(dropout)(x)
    
    x = Conv2D(256, (3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    
    x = Flatten()(x)
    x = Dropout(dropout)(x)
    x = Dense(2, activation='softmax', name='predictions')(x)
    model = Model(inputs, x, name='xception')
    return model

# %%
model_name = 'model' + sensor + '.h5'
model = vanillacnn(0.5)

adam = keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=[metrics.sparse_categorical_accuracy])


checkpoint = ModelCheckpoint(model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
stop = EarlyStopping(patience=20, verbose=1)

callbacks_list = [checkpoint, stop]

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 240, 320, 1)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 120, 160, 32)      320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 120, 160, 32)      128
# _________________________________________________________________
# activation_1 (Activation)    (None, 120, 160, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 60, 80, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60, 80, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 40, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 30, 40, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 40, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 15, 20, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 15, 20, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 10, 128)        73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 10, 128)        512
# _________________________________________________________________
# activation_3 (Activation)    (None, 8, 10, 128)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 5, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 5, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 3, 256)         295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2, 3, 256)         1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 2, 3, 256)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 2, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# predictions (Dense)          (None, 2)                 1026
# =================================================================
# Total params: 390,786
# Trainable params: 389,826
# Non-trainable params: 960
# _________________________________________________________________

# %%
model.fit(x=X_train, 
          y=y_train, 
          batch_size=32, 
          epochs=1000, 
          verbose=1, 
          callbacks=callbacks_list, 
          validation_data=(X_val, y_val), 
          shuffle=True)
# Out:
# Train on 2799 samples, validate on 700 samples
# Epoch 1/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.5720 - sparse_categorical_accuracy: 0.8050Epoch 00000: val_loss improved from inf to 0.51501, saving model to model23.h5
# 2799/2799 [==============================] - 10s - loss: 0.5711 - sparse_categorical_accuracy: 0.8056 - val_loss: 0.5150 - val_sparse_categorical_accuracy: 0.7586
# Epoch 2/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.3516 - sparse_categorical_accuracy: 0.8689Epoch 00001: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.3499 - sparse_categorical_accuracy: 0.8696 - val_loss: 0.5477 - val_sparse_categorical_accuracy: 0.7586
# Epoch 3/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.2963 - sparse_categorical_accuracy: 0.8818Epoch 00002: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.2957 - sparse_categorical_accuracy: 0.8821 - val_loss: 0.5977 - val_sparse_categorical_accuracy: 0.7586
# Epoch 4/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.2627 - sparse_categorical_accuracy: 0.8901Epoch 00003: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.2615 - sparse_categorical_accuracy: 0.8907 - val_loss: 0.6856 - val_sparse_categorical_accuracy: 0.7586
# Epoch 5/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.2465 - sparse_categorical_accuracy: 0.8951Epoch 00004: val_loss improved from 0.51501 to 0.43997, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.2458 - sparse_categorical_accuracy: 0.8957 - val_loss: 0.4400 - val_sparse_categorical_accuracy: 0.7586
# Epoch 6/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.2042 - sparse_categorical_accuracy: 0.9124Epoch 00005: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.2053 - sparse_categorical_accuracy: 0.9125 - val_loss: 0.4522 - val_sparse_categorical_accuracy: 0.7600
# Epoch 7/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.2013 - sparse_categorical_accuracy: 0.9185Epoch 00006: val_loss improved from 0.43997 to 0.39179, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.2020 - sparse_categorical_accuracy: 0.9182 - val_loss: 0.3918 - val_sparse_categorical_accuracy: 0.7729
# Epoch 8/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1930 - sparse_categorical_accuracy: 0.9149Epoch 00007: val_loss improved from 0.39179 to 0.29142, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.1935 - sparse_categorical_accuracy: 0.9146 - val_loss: 0.2914 - val_sparse_categorical_accuracy: 0.8557
# Epoch 9/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1917 - sparse_categorical_accuracy: 0.9213Epoch 00008: val_loss improved from 0.29142 to 0.24766, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.1913 - sparse_categorical_accuracy: 0.9218 - val_loss: 0.2477 - val_sparse_categorical_accuracy: 0.8829
# Epoch 10/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1851 - sparse_categorical_accuracy: 0.9221Epoch 00009: val_loss improved from 0.24766 to 0.21722, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.1844 - sparse_categorical_accuracy: 0.9225 - val_loss: 0.2172 - val_sparse_categorical_accuracy: 0.8900
# Epoch 11/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1774 - sparse_categorical_accuracy: 0.9217Epoch 00010: val_loss improved from 0.21722 to 0.20897, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.1777 - sparse_categorical_accuracy: 0.9218 - val_loss: 0.2090 - val_sparse_categorical_accuracy: 0.8900
# Epoch 12/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1859 - sparse_categorical_accuracy: 0.9253Epoch 00011: val_loss improved from 0.20897 to 0.16621, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.1855 - sparse_categorical_accuracy: 0.9253 - val_loss: 0.1662 - val_sparse_categorical_accuracy: 0.9214
# Epoch 13/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1596 - sparse_categorical_accuracy: 0.9364Epoch 00012: val_loss improved from 0.16621 to 0.15855, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.1607 - sparse_categorical_accuracy: 0.9357 - val_loss: 0.1586 - val_sparse_categorical_accuracy: 0.9257
# Epoch 14/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1578 - sparse_categorical_accuracy: 0.9296Epoch 00013: val_loss improved from 0.15855 to 0.15808, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.1578 - sparse_categorical_accuracy: 0.9296 - val_loss: 0.1581 - val_sparse_categorical_accuracy: 0.9286
# Epoch 15/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1558 - sparse_categorical_accuracy: 0.9332Epoch 00014: val_loss improved from 0.15808 to 0.14241, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.1560 - sparse_categorical_accuracy: 0.9332 - val_loss: 0.1424 - val_sparse_categorical_accuracy: 0.9329
# Epoch 16/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1401 - sparse_categorical_accuracy: 0.9422Epoch 00015: val_loss improved from 0.14241 to 0.13871, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.1401 - sparse_categorical_accuracy: 0.9421 - val_loss: 0.1387 - val_sparse_categorical_accuracy: 0.9400
# Epoch 17/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1412 - sparse_categorical_accuracy: 0.9440Epoch 00016: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.1408 - sparse_categorical_accuracy: 0.9443 - val_loss: 0.1966 - val_sparse_categorical_accuracy: 0.9186
# Epoch 18/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1310 - sparse_categorical_accuracy: 0.9476Epoch 00017: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.1331 - sparse_categorical_accuracy: 0.9471 - val_loss: 0.1388 - val_sparse_categorical_accuracy: 0.9414
# Epoch 19/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1333 - sparse_categorical_accuracy: 0.9461Epoch 00018: val_loss improved from 0.13871 to 0.11786, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.1333 - sparse_categorical_accuracy: 0.9461 - val_loss: 0.1179 - val_sparse_categorical_accuracy: 0.9514
# Epoch 20/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1189 - sparse_categorical_accuracy: 0.9504Epoch 00019: val_loss improved from 0.11786 to 0.11387, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.1204 - sparse_categorical_accuracy: 0.9496 - val_loss: 0.1139 - val_sparse_categorical_accuracy: 0.9529
# Epoch 21/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1213 - sparse_categorical_accuracy: 0.9504Epoch 00020: val_loss improved from 0.11387 to 0.10117, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.1223 - sparse_categorical_accuracy: 0.9503 - val_loss: 0.1012 - val_sparse_categorical_accuracy: 0.9671
# Epoch 22/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1191 - sparse_categorical_accuracy: 0.9555Epoch 00021: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.1192 - sparse_categorical_accuracy: 0.9553 - val_loss: 0.1040 - val_sparse_categorical_accuracy: 0.9557
# Epoch 23/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1158 - sparse_categorical_accuracy: 0.9569Epoch 00022: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.1157 - sparse_categorical_accuracy: 0.9568 - val_loss: 0.1037 - val_sparse_categorical_accuracy: 0.9600
# Epoch 24/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1034 - sparse_categorical_accuracy: 0.9594Epoch 00023: val_loss improved from 0.10117 to 0.09524, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.1039 - sparse_categorical_accuracy: 0.9593 - val_loss: 0.0952 - val_sparse_categorical_accuracy: 0.9600
# Epoch 25/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1088 - sparse_categorical_accuracy: 0.9558Epoch 00024: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.1094 - sparse_categorical_accuracy: 0.9557 - val_loss: 0.1028 - val_sparse_categorical_accuracy: 0.9557
# Epoch 26/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1047 - sparse_categorical_accuracy: 0.9576Epoch 00025: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.1042 - sparse_categorical_accuracy: 0.9578 - val_loss: 0.1032 - val_sparse_categorical_accuracy: 0.9614
# Epoch 27/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1049 - sparse_categorical_accuracy: 0.9573Epoch 00026: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.1048 - sparse_categorical_accuracy: 0.9575 - val_loss: 0.1111 - val_sparse_categorical_accuracy: 0.9543
# Epoch 28/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.1027 - sparse_categorical_accuracy: 0.9565Epoch 00027: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.1027 - sparse_categorical_accuracy: 0.9564 - val_loss: 0.1078 - val_sparse_categorical_accuracy: 0.9600
# Epoch 29/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0951 - sparse_categorical_accuracy: 0.9612Epoch 00028: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0953 - sparse_categorical_accuracy: 0.9607 - val_loss: 0.1068 - val_sparse_categorical_accuracy: 0.9529
# Epoch 30/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0962 - sparse_categorical_accuracy: 0.9619Epoch 00029: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0966 - sparse_categorical_accuracy: 0.9618 - val_loss: 0.1020 - val_sparse_categorical_accuracy: 0.9543
# Epoch 31/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0963 - sparse_categorical_accuracy: 0.9619Epoch 00030: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0962 - sparse_categorical_accuracy: 0.9618 - val_loss: 0.0983 - val_sparse_categorical_accuracy: 0.9557
# Epoch 32/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0942 - sparse_categorical_accuracy: 0.9623Epoch 00031: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.0944 - sparse_categorical_accuracy: 0.9621 - val_loss: 0.1084 - val_sparse_categorical_accuracy: 0.9614
# Epoch 33/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0828 - sparse_categorical_accuracy: 0.9670Epoch 00032: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0825 - sparse_categorical_accuracy: 0.9671 - val_loss: 0.0955 - val_sparse_categorical_accuracy: 0.9629
# Epoch 34/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0838 - sparse_categorical_accuracy: 0.9662Epoch 00033: val_loss improved from 0.09524 to 0.08826, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.0836 - sparse_categorical_accuracy: 0.9664 - val_loss: 0.0883 - val_sparse_categorical_accuracy: 0.9657
# Epoch 35/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0871 - sparse_categorical_accuracy: 0.9652Epoch 00034: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0872 - sparse_categorical_accuracy: 0.9650 - val_loss: 0.0997 - val_sparse_categorical_accuracy: 0.9614
# Epoch 36/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0732 - sparse_categorical_accuracy: 0.9698Epoch 00035: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0730 - sparse_categorical_accuracy: 0.9700 - val_loss: 0.0893 - val_sparse_categorical_accuracy: 0.9629
# Epoch 37/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0885 - sparse_categorical_accuracy: 0.9644Epoch 00036: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0885 - sparse_categorical_accuracy: 0.9643 - val_loss: 0.0908 - val_sparse_categorical_accuracy: 0.9700
# Epoch 38/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0847 - sparse_categorical_accuracy: 0.9709Epoch 00037: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0844 - sparse_categorical_accuracy: 0.9711 - val_loss: 0.0884 - val_sparse_categorical_accuracy: 0.9714
# Epoch 39/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0802 - sparse_categorical_accuracy: 0.9688Epoch 00038: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0798 - sparse_categorical_accuracy: 0.9689 - val_loss: 0.0922 - val_sparse_categorical_accuracy: 0.9686
# Epoch 40/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0711 - sparse_categorical_accuracy: 0.9716Epoch 00039: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0711 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0965 - val_sparse_categorical_accuracy: 0.9600
# Epoch 41/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0723 - sparse_categorical_accuracy: 0.9705Epoch 00040: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0723 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0886 - val_sparse_categorical_accuracy: 0.9671
# Epoch 42/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0847 - sparse_categorical_accuracy: 0.9655Epoch 00041: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0843 - sparse_categorical_accuracy: 0.9657 - val_loss: 0.0960 - val_sparse_categorical_accuracy: 0.9743
# Epoch 43/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0840 - sparse_categorical_accuracy: 0.9670Epoch 00042: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0835 - sparse_categorical_accuracy: 0.9671 - val_loss: 0.0953 - val_sparse_categorical_accuracy: 0.9729
# Epoch 44/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0734 - sparse_categorical_accuracy: 0.9727Epoch 00043: val_loss improved from 0.08826 to 0.08614, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.0736 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0861 - val_sparse_categorical_accuracy: 0.9671
# Epoch 45/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0746 - sparse_categorical_accuracy: 0.9705Epoch 00044: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0748 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0948 - val_sparse_categorical_accuracy: 0.9729
# Epoch 46/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0754 - sparse_categorical_accuracy: 0.9688Epoch 00045: val_loss improved from 0.08614 to 0.08464, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.0752 - sparse_categorical_accuracy: 0.9689 - val_loss: 0.0846 - val_sparse_categorical_accuracy: 0.9686
# Epoch 47/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0688 - sparse_categorical_accuracy: 0.9749Epoch 00046: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.0692 - sparse_categorical_accuracy: 0.9746 - val_loss: 0.0992 - val_sparse_categorical_accuracy: 0.9657
# Epoch 48/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0740 - sparse_categorical_accuracy: 0.9745Epoch 00047: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.0737 - sparse_categorical_accuracy: 0.9746 - val_loss: 0.0854 - val_sparse_categorical_accuracy: 0.9686
# Epoch 49/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0691 - sparse_categorical_accuracy: 0.9741Epoch 00048: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0689 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.1003 - val_sparse_categorical_accuracy: 0.9657
# Epoch 50/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0747 - sparse_categorical_accuracy: 0.9677Epoch 00049: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.0743 - sparse_categorical_accuracy: 0.9678 - val_loss: 0.0875 - val_sparse_categorical_accuracy: 0.9729
# Epoch 51/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0677 - sparse_categorical_accuracy: 0.9731Epoch 00050: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0674 - sparse_categorical_accuracy: 0.9732 - val_loss: 0.0889 - val_sparse_categorical_accuracy: 0.9729
# Epoch 52/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0679 - sparse_categorical_accuracy: 0.9759Epoch 00051: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0676 - sparse_categorical_accuracy: 0.9761 - val_loss: 0.0896 - val_sparse_categorical_accuracy: 0.9700
# Epoch 53/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0608 - sparse_categorical_accuracy: 0.9752Epoch 00052: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.0606 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.0966 - val_sparse_categorical_accuracy: 0.9757
# Epoch 54/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0661 - sparse_categorical_accuracy: 0.9752Epoch 00053: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.0657 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.0933 - val_sparse_categorical_accuracy: 0.9743
# Epoch 55/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0690 - sparse_categorical_accuracy: 0.9756Epoch 00054: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.0687 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.0885 - val_sparse_categorical_accuracy: 0.9743
# Epoch 56/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0636 - sparse_categorical_accuracy: 0.9770Epoch 00055: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0634 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.0919 - val_sparse_categorical_accuracy: 0.9729
# Epoch 57/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0593 - sparse_categorical_accuracy: 0.9745Epoch 00056: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0597 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.0928 - val_sparse_categorical_accuracy: 0.9671
# Epoch 58/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0635 - sparse_categorical_accuracy: 0.9770Epoch 00057: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0636 - sparse_categorical_accuracy: 0.9768 - val_loss: 0.0901 - val_sparse_categorical_accuracy: 0.9729
# Epoch 59/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0566 - sparse_categorical_accuracy: 0.9792Epoch 00058: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0563 - sparse_categorical_accuracy: 0.9793 - val_loss: 0.1021 - val_sparse_categorical_accuracy: 0.9629
# Epoch 60/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0573 - sparse_categorical_accuracy: 0.9784Epoch 00059: val_loss improved from 0.08464 to 0.08231, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.0571 - sparse_categorical_accuracy: 0.9786 - val_loss: 0.0823 - val_sparse_categorical_accuracy: 0.9700
# Epoch 61/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0564 - sparse_categorical_accuracy: 0.9738Epoch 00060: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0561 - sparse_categorical_accuracy: 0.9739 - val_loss: 0.1232 - val_sparse_categorical_accuracy: 0.9629
# Epoch 62/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0574 - sparse_categorical_accuracy: 0.9781Epoch 00061: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.0571 - sparse_categorical_accuracy: 0.9782 - val_loss: 0.1192 - val_sparse_categorical_accuracy: 0.9671
# Epoch 63/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0520 - sparse_categorical_accuracy: 0.9788Epoch 00062: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.0517 - sparse_categorical_accuracy: 0.9789 - val_loss: 0.1006 - val_sparse_categorical_accuracy: 0.9700
# Epoch 64/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0479 - sparse_categorical_accuracy: 0.9835Epoch 00063: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0478 - sparse_categorical_accuracy: 0.9836 - val_loss: 0.0855 - val_sparse_categorical_accuracy: 0.9771
# Epoch 65/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0601 - sparse_categorical_accuracy: 0.9781Epoch 00064: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0597 - sparse_categorical_accuracy: 0.9782 - val_loss: 0.0936 - val_sparse_categorical_accuracy: 0.9657
# Epoch 66/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0599 - sparse_categorical_accuracy: 0.9770Epoch 00065: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0597 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.0930 - val_sparse_categorical_accuracy: 0.9729
# Epoch 67/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0549 - sparse_categorical_accuracy: 0.9799Epoch 00066: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0548 - sparse_categorical_accuracy: 0.9800 - val_loss: 0.0991 - val_sparse_categorical_accuracy: 0.9729
# Epoch 68/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0507 - sparse_categorical_accuracy: 0.9824Epoch 00067: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0513 - sparse_categorical_accuracy: 0.9818 - val_loss: 0.0920 - val_sparse_categorical_accuracy: 0.9743
# Epoch 69/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0511 - sparse_categorical_accuracy: 0.9817Epoch 00068: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0509 - sparse_categorical_accuracy: 0.9818 - val_loss: 0.0935 - val_sparse_categorical_accuracy: 0.9743
# Epoch 70/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0558 - sparse_categorical_accuracy: 0.9784Epoch 00069: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0556 - sparse_categorical_accuracy: 0.9786 - val_loss: 0.0882 - val_sparse_categorical_accuracy: 0.9700
# Epoch 71/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0514 - sparse_categorical_accuracy: 0.9784Epoch 00070: val_loss improved from 0.08231 to 0.08145, saving model to model23.h5
# 2799/2799 [==============================] - 9s - loss: 0.0517 - sparse_categorical_accuracy: 0.9782 - val_loss: 0.0815 - val_sparse_categorical_accuracy: 0.9729
# Epoch 72/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0419 - sparse_categorical_accuracy: 0.9842Epoch 00071: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0423 - sparse_categorical_accuracy: 0.9839 - val_loss: 0.0889 - val_sparse_categorical_accuracy: 0.9686
# Epoch 73/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0578 - sparse_categorical_accuracy: 0.9799Epoch 00072: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0579 - sparse_categorical_accuracy: 0.9800 - val_loss: 0.0869 - val_sparse_categorical_accuracy: 0.9743
# Epoch 74/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0454 - sparse_categorical_accuracy: 0.9849Epoch 00073: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0452 - sparse_categorical_accuracy: 0.9850 - val_loss: 0.0908 - val_sparse_categorical_accuracy: 0.9743
# Epoch 75/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0552 - sparse_categorical_accuracy: 0.9759Epoch 00074: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0550 - sparse_categorical_accuracy: 0.9761 - val_loss: 0.0959 - val_sparse_categorical_accuracy: 0.9729
# Epoch 76/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0450 - sparse_categorical_accuracy: 0.9828Epoch 00075: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0449 - sparse_categorical_accuracy: 0.9829 - val_loss: 0.0973 - val_sparse_categorical_accuracy: 0.9729
# Epoch 77/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0538 - sparse_categorical_accuracy: 0.9795Epoch 00076: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0543 - sparse_categorical_accuracy: 0.9793 - val_loss: 0.0989 - val_sparse_categorical_accuracy: 0.9729
# Epoch 78/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0440 - sparse_categorical_accuracy: 0.9828Epoch 00077: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.0440 - sparse_categorical_accuracy: 0.9829 - val_loss: 0.1145 - val_sparse_categorical_accuracy: 0.9686
# Epoch 79/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0437 - sparse_categorical_accuracy: 0.9828Epoch 00078: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0435 - sparse_categorical_accuracy: 0.9829 - val_loss: 0.1225 - val_sparse_categorical_accuracy: 0.9686
# Epoch 80/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0495 - sparse_categorical_accuracy: 0.9824Epoch 00079: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0498 - sparse_categorical_accuracy: 0.9821 - val_loss: 0.0883 - val_sparse_categorical_accuracy: 0.9700
# Epoch 81/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0463 - sparse_categorical_accuracy: 0.9820Epoch 00080: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0463 - sparse_categorical_accuracy: 0.9818 - val_loss: 0.0901 - val_sparse_categorical_accuracy: 0.9686
# Epoch 82/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0415 - sparse_categorical_accuracy: 0.9842Epoch 00081: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0435 - sparse_categorical_accuracy: 0.9839 - val_loss: 0.0838 - val_sparse_categorical_accuracy: 0.9743
# Epoch 83/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0466 - sparse_categorical_accuracy: 0.9835Epoch 00082: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0464 - sparse_categorical_accuracy: 0.9836 - val_loss: 0.0916 - val_sparse_categorical_accuracy: 0.9700
# Epoch 84/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0479 - sparse_categorical_accuracy: 0.9806Epoch 00083: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0477 - sparse_categorical_accuracy: 0.9807 - val_loss: 0.0874 - val_sparse_categorical_accuracy: 0.9800
# Epoch 85/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0407 - sparse_categorical_accuracy: 0.9860Epoch 00084: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0414 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.0941 - val_sparse_categorical_accuracy: 0.9714
# Epoch 86/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0464 - sparse_categorical_accuracy: 0.9831Epoch 00085: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.0465 - sparse_categorical_accuracy: 0.9829 - val_loss: 0.0888 - val_sparse_categorical_accuracy: 0.9757
# Epoch 87/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0460 - sparse_categorical_accuracy: 0.9828Epoch 00086: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.0459 - sparse_categorical_accuracy: 0.9829 - val_loss: 0.1061 - val_sparse_categorical_accuracy: 0.9686
# Epoch 88/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0437 - sparse_categorical_accuracy: 0.9838Epoch 00087: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0452 - sparse_categorical_accuracy: 0.9836 - val_loss: 0.0988 - val_sparse_categorical_accuracy: 0.9771
# Epoch 89/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0498 - sparse_categorical_accuracy: 0.9817Epoch 00088: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.0503 - sparse_categorical_accuracy: 0.9814 - val_loss: 0.1010 - val_sparse_categorical_accuracy: 0.9729
# Epoch 90/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0343 - sparse_categorical_accuracy: 0.9846Epoch 00089: val_loss did not improve
# 2799/2799 [==============================] - 9s - loss: 0.0341 - sparse_categorical_accuracy: 0.9846 - val_loss: 0.1033 - val_sparse_categorical_accuracy: 0.9743
# Epoch 91/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0512 - sparse_categorical_accuracy: 0.9813Epoch 00090: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0509 - sparse_categorical_accuracy: 0.9814 - val_loss: 0.1079 - val_sparse_categorical_accuracy: 0.9700
# Epoch 92/1000
# 2784/2799 [============================>.] - ETA: 0s - loss: 0.0436 - sparse_categorical_accuracy: 0.9849Epoch 00091: val_loss did not improve
# 2799/2799 [==============================] - 8s - loss: 0.0434 - sparse_categorical_accuracy: 0.9850 - val_loss: 0.0960 - val_sparse_categorical_accuracy: 0.9714
# Epoch 00091: early stopping

# %%
from keras.models import load_model
trained_model = load_model(model_name)
print(trained_model.metrics_names)
trained_model.evaluate(x=X_train, y=y_train)
# Out:
# ['loss', 'sparse_categorical_accuracy']
# 2784/2799 [============================>.] - ETA: 0s
# [0.013818885857915148, 0.99714183671085188]

# %%
trained_model.evaluate(x=X_val, y=y_val)
# Out:
# 672/700 [===========================>..] - ETA: 0s
# [0.081454916081524317, 0.97285714353833874]
