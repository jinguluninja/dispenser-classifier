# %%
import os
import keras
import numpy as np
np.random.seed(135109)
# Out:
# Using TensorFlow backend.

# %%
sensor = '22'

# %%
def dataset():
    X = []
    y = []
    data_dir_0 = sorted(os.listdir(os.path.join('pac_data', sensor, '0')))   
    i = 0
    for f in data_dir_0:
        if i % 100 == 0: print(i)
        i += 1
        X.append(np.load(os.path.join('pac_data', sensor, '0', f))['x'])
        y.append(0)
    X = np.asarray(X, dtype=np.float16)
    y = np.asarray(y, dtype=int)
    indices = np.arange(y.shape[0])
    np.random.shuffle(indices)
    X_train = X[indices[:int(0.8*len(indices))]]
    y_train = y[indices[:int(0.8*len(indices))]]
    X_val = X[indices[int(0.8*len(indices)):]]
    y_val = y[indices[int(0.8*len(indices)):]]
    labels_present = os.listdir(os.path.join('pac_data', sensor))
    if '1' in labels_present:
        X = []
        y = []
        data_dir_1 = sorted(os.listdir(os.path.join('pac_data', sensor, '1')))
        i = 0
        for f in data_dir_1:
            if i % 100 == 0: print(i)
            i += 1
            X.append(np.load(os.path.join('pac_data', sensor, '1', f))['x'])
            y.append(1)        
        X = np.asarray(X, dtype=np.float16)
        y = np.asarray(y, dtype=int)
        indices = np.arange(y.shape[0])
        np.random.shuffle(indices)
        X_train = np.concatenate([X_train, X[indices[:int(0.8*len(indices))]]])
        y_train = np.concatenate([y_train, y[indices[:int(0.8*len(indices))]]])
        X_val = np.concatenate([X_val, X[indices[int(0.8*len(indices)):]]])
        y_val = np.concatenate([y_val, y[indices[int(0.8*len(indices)):]]])
    X_train = np.expand_dims(np.asarray(X_train, dtype=np.float16), axis=3)
    y_train = np.asarray(y_train, dtype=int)
    X_val = np.expand_dims(np.asarray(X_val, dtype=np.float16), axis=3)
    y_val = np.asarray(y_val, dtype=int)
    X_train /= 5.
    X_val /= 5.
    mean_arr = np.mean(X_train, axis = 0)
    np.save(os.path.join('pac_data', sensor, 'mean.npy'), mean_arr)
    X_train -= mean_arr 
    X_val -= mean_arr  
    return X_train, y_train, X_val, y_val

# %%
X_train, y_train, X_val, y_val = dataset()
# Out:
# 0

# %%
print(X_train.shape, y_train.shape, X_val.shape, y_val.shape)
# Out:
# (14, 240, 320, 1) (14,) (4, 240, 320, 1) (4,)

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/gpu:0']

# %%
from keras.models import Sequential
from keras.layers import TimeDistributed, GlobalAveragePooling2D, Activation, Dense, Input
from keras.layers import BatchNormalization, Conv2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D
from keras.layers import GlobalMaxPooling2D
from keras.layers.recurrent import LSTM
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras.layers import Dropout, Flatten
from keras.layers import concatenate
from keras import regularizers
from keras import initializers
from keras import constraints
from keras.models import Model
from keras import backend as K
from keras.utils.layer_utils import convert_all_kernels_in_model
from keras.utils.data_utils import get_file
from keras.utils import conv_utils
from keras.engine.topology import get_source_inputs
from keras.engine import InputSpec
from keras.applications.xception import Xception
from keras import metrics

# %%
#linear
def linear(dropout):
    inputs = Input(shape=(240, 320, 1))
    x = Flatten()(inputs)
    x = Dropout(dropout)(x)
    x = Dense(2, activation='softmax')(x)
    model = Model(inputs, x, name='linear')
    return model

# %%
from keras import layers
from keras.layers import Activation
from keras.layers import SeparableConv2D

def xception(dropout):
    inputs = Input(shape=(240, 320, 1))    

    x = Conv2D(32, (3, 3), padding='same', strides=(2, 2), use_bias=False, name='block1_conv1')(inputs)
    x = BatchNormalization(name='block1_conv1_bn')(x)
    x = Activation('relu', name='block1_conv1_act')(x)
    x = Conv2D(64, (3, 3), padding='same', use_bias=False, name='block1_conv2')(x)
    x = BatchNormalization(name='block1_conv2_bn')(x)
    x = Activation('relu', name='block1_conv2_act')(x)

    residual = Conv2D(128, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, name='block2_sepconv1')(x)
    x = BatchNormalization(name='block2_sepconv1_bn')(x)
    x = Activation('relu', name='block2_sepconv2_act')(x)
    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, name='block2_sepconv2')(x)
    x = BatchNormalization(name='block2_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block2_pool')(x)
    x = layers.add([x, residual])

    residual = Conv2D(256, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block3_sepconv1_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, name='block3_sepconv1')(x)
    x = BatchNormalization(name='block3_sepconv1_bn')(x)
    x = Activation('relu', name='block3_sepconv2_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, name='block3_sepconv2')(x)
    x = BatchNormalization(name='block3_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block3_pool')(x)
    x = layers.add([x, residual])

    residual = Conv2D(728, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block4_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name='block4_sepconv1')(x)
    x = BatchNormalization(name='block4_sepconv1_bn')(x)
    x = Activation('relu', name='block4_sepconv2_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name='block4_sepconv2')(x)
    x = BatchNormalization(name='block4_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block4_pool')(x)
    x = layers.add([x, residual])

    for i in range(8):
        residual = x
        prefix = 'block' + str(i + 5)

        x = Activation('relu', name=prefix + '_sepconv1_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name=prefix + '_sepconv1')(x)
        x = BatchNormalization(name=prefix + '_sepconv1_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv2_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name=prefix + '_sepconv2')(x)
        x = BatchNormalization(name=prefix + '_sepconv2_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv3_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name=prefix + '_sepconv3')(x)
        x = BatchNormalization(name=prefix + '_sepconv3_bn')(x)

        x = layers.add([x, residual])

    residual = Conv2D(1024, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False)(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block13_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, name='block13_sepconv1')(x)
    x = BatchNormalization(name='block13_sepconv1_bn')(x)
    x = Activation('relu', name='block13_sepconv2_act')(x)
    x = SeparableConv2D(1024, (3, 3), padding='same', use_bias=False, name='block13_sepconv2')(x)
    x = BatchNormalization(name='block13_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block13_pool')(x)
    x = layers.add([x, residual])

    x = SeparableConv2D(1536, (3, 3), padding='same', use_bias=False, name='block14_sepconv1')(x)
    x = BatchNormalization(name='block14_sepconv1_bn')(x)
    x = Activation('relu', name='block14_sepconv1_act')(x)

    x = SeparableConv2D(2048, (3, 3), padding='same', use_bias=False, name='block14_sepconv2')(x)
    x = BatchNormalization(name='block14_sepconv2_bn')(x)
    x = Activation('relu', name='block14_sepconv2_act')(x)

    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dropout(dropout)(x)
    x = Dense(2, activation='softmax', name='predictions')(x)
    model = Model(inputs, x, name='xception')
    return model


'''
def xception(dropout):
    base_model = Xception(include_top=False, input_shape = (240, 320, 1), pooling='avg')
    x = base_model.output
    x = Flatten()(x)
    x = Dropout(dropout)(x) # drop prob
    predictions = Dense(2, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions, name='linear')
    return model
'''
# Out:
# "\ndef xception(dropout):\n    base_model = Xception(include_top=False, input_shape = (240, 320, 1), pooling='avg')\n    x = base_model.output\n    x = Flatten()(x)\n    x = Dropout(dropout)(x) # drop prob\n    predictions = Dense(2, activation='softmax')(x)\n    model = Model(inputs=base_model.input, outputs=predictions, name='linear')\n    return model\n"

# %%
def vanillacnn(dropout):
    inputs = Input(shape=(240, 320, 1)) 
    x = Conv2D(32, (3, 3), strides=(2, 2), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = Dropout(dropout)(x)
    
    x = Conv2D(64, (3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = Dropout(dropout)(x)
    
    x = Conv2D(128, (3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    x = Dropout(dropout)(x)
    
    x = Conv2D(256, (3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    
    x = Flatten()(x)
    x = Dropout(dropout)(x)
    x = Dense(2, activation='softmax', name='predictions')(x)
    model = Model(inputs, x, name='xception')
    return model

# %%
model_name = 'model' + sensor + '.h5'
model = vanillacnn(0.5)

adam = keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=[metrics.sparse_categorical_accuracy])


checkpoint = ModelCheckpoint(model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
stop = EarlyStopping(patience=20, verbose=1)

callbacks_list = [checkpoint, stop]

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 240, 320, 1)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 120, 160, 32)      320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 120, 160, 32)      128
# _________________________________________________________________
# activation_1 (Activation)    (None, 120, 160, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 60, 80, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60, 80, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 40, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 30, 40, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 40, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 15, 20, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 15, 20, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 10, 128)        73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 10, 128)        512
# _________________________________________________________________
# activation_3 (Activation)    (None, 8, 10, 128)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 5, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 5, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 3, 256)         295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2, 3, 256)         1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 2, 3, 256)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 2, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# predictions (Dense)          (None, 2)                 1026
# =================================================================
# Total params: 390,786
# Trainable params: 389,826
# Non-trainable params: 960
# _________________________________________________________________

# %%
model.fit(x=X_train, 
          y=y_train, 
          batch_size=32, 
          epochs=100, 
          verbose=1, 
          callbacks=callbacks_list, 
          validation_data=(X_val, y_val), 
          shuffle=True)
# Out:
# Train on 14 samples, validate on 4 samples
# Epoch 1/100
# Epoch 00000: val_loss improved from inf to 0.65750, saving model to model22.h5
# 14/14 [==============================] - 1s - loss: 2.1890 - sparse_categorical_accuracy: 0.2857 - val_loss: 0.6575 - val_sparse_categorical_accuracy: 1.0000
# Epoch 2/100
# Epoch 00001: val_loss improved from 0.65750 to 0.58936, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.0353 - sparse_categorical_accuracy: 0.5714 - val_loss: 0.5894 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/100
# Epoch 00002: val_loss improved from 0.58936 to 0.53658, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 0.0217 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5366 - val_sparse_categorical_accuracy: 1.0000
# Epoch 4/100
# Epoch 00003: val_loss improved from 0.53658 to 0.49744, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 0.0074 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4974 - val_sparse_categorical_accuracy: 1.0000
# Epoch 5/100
# Epoch 00004: val_loss improved from 0.49744 to 0.46561, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4656 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/100
# Epoch 00005: val_loss improved from 0.46561 to 0.44051, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 8.3605e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4405 - val_sparse_categorical_accuracy: 1.0000
# Epoch 7/100
# Epoch 00006: val_loss improved from 0.44051 to 0.41979, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.6122e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4198 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/100
# Epoch 00007: val_loss improved from 0.41979 to 0.40040, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 4.1127e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4004 - val_sparse_categorical_accuracy: 1.0000
# Epoch 9/100
# Epoch 00008: val_loss improved from 0.40040 to 0.38105, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 5.4835e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3810 - val_sparse_categorical_accuracy: 1.0000
# Epoch 10/100
# Epoch 00009: val_loss improved from 0.38105 to 0.36306, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 4.1893e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3631 - val_sparse_categorical_accuracy: 1.0000
# Epoch 11/100
# Epoch 00010: val_loss improved from 0.36306 to 0.34514, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 5.7714e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3451 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/100
# Epoch 00011: val_loss improved from 0.34514 to 0.32691, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 3.2357e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3269 - val_sparse_categorical_accuracy: 1.0000
# Epoch 13/100
# Epoch 00012: val_loss improved from 0.32691 to 0.30978, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 4.6150e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3098 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/100
# Epoch 00013: val_loss improved from 0.30978 to 0.29372, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 8.7869e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2937 - val_sparse_categorical_accuracy: 1.0000
# Epoch 15/100
# Epoch 00014: val_loss improved from 0.29372 to 0.27828, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.5327e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2783 - val_sparse_categorical_accuracy: 1.0000
# Epoch 16/100
# Epoch 00015: val_loss improved from 0.27828 to 0.26342, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 2.3671e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2634 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/100
# Epoch 00016: val_loss improved from 0.26342 to 0.24898, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 2.7248e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2490 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/100
# Epoch 00017: val_loss improved from 0.24898 to 0.23517, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.0899e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2352 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/100
# Epoch 00018: val_loss improved from 0.23517 to 0.22247, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 3.0654e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2225 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/100
# Epoch 00019: val_loss improved from 0.22247 to 0.21090, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 4.4278e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2109 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/100
# Epoch 00020: val_loss improved from 0.21090 to 0.19861, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.4475e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1986 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/100
# Epoch 00021: val_loss improved from 0.19861 to 0.18715, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 3.5763e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1871 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/100
# Epoch 00022: val_loss improved from 0.18715 to 0.17693, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.7030e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1769 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/100
# Epoch 00023: val_loss improved from 0.17693 to 0.16682, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 2.2139e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1668 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/100
# Epoch 00024: val_loss improved from 0.16682 to 0.15757, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.2772e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1576 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/100
# Epoch 00025: val_loss improved from 0.15757 to 0.14911, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.2772e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1491 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/100
# Epoch 00026: val_loss improved from 0.14911 to 0.14161, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 2.2990e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1416 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/100
# Epoch 00027: val_loss improved from 0.14161 to 0.13448, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.7030e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1345 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/100
# Epoch 00028: val_loss improved from 0.13448 to 0.12766, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1277 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/100
# Epoch 00029: val_loss improved from 0.12766 to 0.12131, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.4475e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1213 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/100
# Epoch 00030: val_loss improved from 0.12131 to 0.11554, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.4475e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1155 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/100
# Epoch 00031: val_loss improved from 0.11554 to 0.11029, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.6178e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1103 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/100
# Epoch 00032: val_loss improved from 0.11029 to 0.10498, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.2772e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1050 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/100
# Epoch 00033: val_loss improved from 0.10498 to 0.10023, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1002 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/100
# Epoch 00034: val_loss improved from 0.10023 to 0.09597, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0960 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/100
# Epoch 00035: val_loss improved from 0.09597 to 0.09195, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0920 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/100
# Epoch 00036: val_loss improved from 0.09195 to 0.08831, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0883 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/100
# Epoch 00037: val_loss improved from 0.08831 to 0.08455, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.2772e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0846 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/100
# Epoch 00038: val_loss improved from 0.08455 to 0.08118, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.3624e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0812 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/100
# Epoch 00039: val_loss improved from 0.08118 to 0.07789, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0779 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/100
# Epoch 00040: val_loss improved from 0.07789 to 0.07477, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0748 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/100
# Epoch 00041: val_loss improved from 0.07477 to 0.07181, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.3624e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0718 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/100
# Epoch 00042: val_loss improved from 0.07181 to 0.06916, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0692 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/100
# Epoch 00043: val_loss improved from 0.06916 to 0.06681, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0668 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/100
# Epoch 00044: val_loss improved from 0.06681 to 0.06444, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0644 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/100
# Epoch 00045: val_loss improved from 0.06444 to 0.06208, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0621 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/100
# Epoch 00046: val_loss improved from 0.06208 to 0.06001, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.2772e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0600 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/100
# Epoch 00047: val_loss improved from 0.06001 to 0.05805, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0580 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/100
# Epoch 00048: val_loss improved from 0.05805 to 0.05614, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.4475e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0561 - val_sparse_categorical_accuracy: 1.0000
# Epoch 50/100
# Epoch 00049: val_loss improved from 0.05614 to 0.05446, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0545 - val_sparse_categorical_accuracy: 1.0000
# Epoch 51/100
# Epoch 00050: val_loss improved from 0.05446 to 0.05267, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 6.3010e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0527 - val_sparse_categorical_accuracy: 1.0000
# Epoch 52/100
# Epoch 00051: val_loss improved from 0.05267 to 0.05090, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.7881e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0509 - val_sparse_categorical_accuracy: 1.0000
# Epoch 53/100
# Epoch 00052: val_loss improved from 0.05090 to 0.04938, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.3624e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0494 - val_sparse_categorical_accuracy: 1.0000
# Epoch 54/100
# Epoch 00053: val_loss improved from 0.04938 to 0.04784, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0478 - val_sparse_categorical_accuracy: 1.0000
# Epoch 55/100
# Epoch 00054: val_loss improved from 0.04784 to 0.04641, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0464 - val_sparse_categorical_accuracy: 1.0000
# Epoch 56/100
# Epoch 00055: val_loss improved from 0.04641 to 0.04503, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.2772e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0450 - val_sparse_categorical_accuracy: 1.0000
# Epoch 57/100
# Epoch 00056: val_loss improved from 0.04503 to 0.04367, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0437 - val_sparse_categorical_accuracy: 1.0000
# Epoch 58/100
# Epoch 00057: val_loss improved from 0.04367 to 0.04251, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.2772e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0425 - val_sparse_categorical_accuracy: 1.0000
# Epoch 59/100
# Epoch 00058: val_loss improved from 0.04251 to 0.04133, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.3624e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0413 - val_sparse_categorical_accuracy: 1.0000
# Epoch 60/100
# Epoch 00059: val_loss improved from 0.04133 to 0.04034, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.3624e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0403 - val_sparse_categorical_accuracy: 1.0000
# Epoch 61/100
# Epoch 00060: val_loss improved from 0.04034 to 0.03927, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.7881e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0393 - val_sparse_categorical_accuracy: 1.0000
# Epoch 62/100
# Epoch 00061: val_loss improved from 0.03927 to 0.03828, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.7881e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0383 - val_sparse_categorical_accuracy: 1.0000
# Epoch 63/100
# Epoch 00062: val_loss improved from 0.03828 to 0.03735, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.2772e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0374 - val_sparse_categorical_accuracy: 1.0000
# Epoch 64/100
# Epoch 00063: val_loss improved from 0.03735 to 0.03649, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0365 - val_sparse_categorical_accuracy: 1.0000
# Epoch 65/100
# Epoch 00064: val_loss improved from 0.03649 to 0.03557, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 6.7268e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0356 - val_sparse_categorical_accuracy: 1.0000
# Epoch 66/100
# Epoch 00065: val_loss improved from 0.03557 to 0.03477, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0348 - val_sparse_categorical_accuracy: 1.0000
# Epoch 67/100
# Epoch 00066: val_loss improved from 0.03477 to 0.03401, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0340 - val_sparse_categorical_accuracy: 1.0000
# Epoch 68/100
# Epoch 00067: val_loss improved from 0.03401 to 0.03324, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0332 - val_sparse_categorical_accuracy: 1.0000
# Epoch 69/100
# Epoch 00068: val_loss improved from 0.03324 to 0.03258, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.4475e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0326 - val_sparse_categorical_accuracy: 1.0000
# Epoch 70/100
# Epoch 00069: val_loss improved from 0.03258 to 0.03183, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0318 - val_sparse_categorical_accuracy: 1.0000
# Epoch 71/100
# Epoch 00070: val_loss improved from 0.03183 to 0.03116, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0312 - val_sparse_categorical_accuracy: 1.0000
# Epoch 72/100
# Epoch 00071: val_loss improved from 0.03116 to 0.03051, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.7881e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0305 - val_sparse_categorical_accuracy: 1.0000
# Epoch 73/100
# Epoch 00072: val_loss improved from 0.03051 to 0.02975, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0298 - val_sparse_categorical_accuracy: 1.0000
# Epoch 74/100
# Epoch 00073: val_loss improved from 0.02975 to 0.02913, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.2772e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0291 - val_sparse_categorical_accuracy: 1.0000
# Epoch 75/100
# Epoch 00074: val_loss improved from 0.02913 to 0.02851, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 2.0436e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0285 - val_sparse_categorical_accuracy: 1.0000
# Epoch 76/100
# Epoch 00075: val_loss improved from 0.02851 to 0.02792, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0279 - val_sparse_categorical_accuracy: 1.0000
# Epoch 77/100
# Epoch 00076: val_loss improved from 0.02792 to 0.02731, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.8733e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0273 - val_sparse_categorical_accuracy: 1.0000
# Epoch 78/100
# Epoch 00077: val_loss improved from 0.02731 to 0.02674, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.7030e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0267 - val_sparse_categorical_accuracy: 1.0000
# Epoch 79/100
# Epoch 00078: val_loss improved from 0.02674 to 0.02622, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0262 - val_sparse_categorical_accuracy: 1.0000
# Epoch 80/100
# Epoch 00079: val_loss improved from 0.02622 to 0.02568, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0257 - val_sparse_categorical_accuracy: 1.0000
# Epoch 81/100
# Epoch 00080: val_loss improved from 0.02568 to 0.02524, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0252 - val_sparse_categorical_accuracy: 1.0000
# Epoch 82/100
# Epoch 00081: val_loss improved from 0.02524 to 0.02480, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.7881e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0248 - val_sparse_categorical_accuracy: 1.0000
# Epoch 83/100
# Epoch 00082: val_loss improved from 0.02480 to 0.02432, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0243 - val_sparse_categorical_accuracy: 1.0000
# Epoch 84/100
# Epoch 00083: val_loss improved from 0.02432 to 0.02388, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 4.7684e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0239 - val_sparse_categorical_accuracy: 1.0000
# Epoch 85/100
# Epoch 00084: val_loss improved from 0.02388 to 0.02349, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.2772e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0235 - val_sparse_categorical_accuracy: 1.0000
# Epoch 86/100
# Epoch 00085: val_loss improved from 0.02349 to 0.02306, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0231 - val_sparse_categorical_accuracy: 1.0000
# Epoch 87/100
# Epoch 00086: val_loss improved from 0.02306 to 0.02266, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0227 - val_sparse_categorical_accuracy: 1.0000
# Epoch 88/100
# Epoch 00087: val_loss improved from 0.02266 to 0.02229, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0223 - val_sparse_categorical_accuracy: 1.0000
# Epoch 89/100
# Epoch 00088: val_loss improved from 0.02229 to 0.02182, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 4.5129e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0218 - val_sparse_categorical_accuracy: 1.0000
# Epoch 90/100
# Epoch 00089: val_loss improved from 0.02182 to 0.02149, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.3624e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0215 - val_sparse_categorical_accuracy: 1.0000
# Epoch 91/100
# Epoch 00090: val_loss improved from 0.02149 to 0.02110, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.6178e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0211 - val_sparse_categorical_accuracy: 1.0000
# Epoch 92/100
# Epoch 00091: val_loss improved from 0.02110 to 0.02078, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 2.1287e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0208 - val_sparse_categorical_accuracy: 1.0000
# Epoch 93/100
# Epoch 00092: val_loss improved from 0.02078 to 0.02046, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0205 - val_sparse_categorical_accuracy: 1.0000
# Epoch 94/100
# Epoch 00093: val_loss improved from 0.02046 to 0.02010, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0201 - val_sparse_categorical_accuracy: 1.0000
# Epoch 95/100
# Epoch 00094: val_loss improved from 0.02010 to 0.01980, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0198 - val_sparse_categorical_accuracy: 1.0000
# Epoch 96/100
# Epoch 00095: val_loss improved from 0.01980 to 0.01950, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0195 - val_sparse_categorical_accuracy: 1.0000
# Epoch 97/100
# Epoch 00096: val_loss improved from 0.01950 to 0.01923, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0192 - val_sparse_categorical_accuracy: 1.0000
# Epoch 98/100
# Epoch 00097: val_loss improved from 0.01923 to 0.01893, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.6178e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0189 - val_sparse_categorical_accuracy: 1.0000
# Epoch 99/100
# Epoch 00098: val_loss improved from 0.01893 to 0.01866, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0187 - val_sparse_categorical_accuracy: 1.0000
# Epoch 100/100
# Epoch 00099: val_loss improved from 0.01866 to 0.01839, saving model to model22.h5
# 14/14 [==============================] - 0s - loss: 1.1921e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0184 - val_sparse_categorical_accuracy: 1.0000

# %%
from keras.models import load_model
trained_model = load_model(model_name)
print(trained_model.metrics_names)
trained_model.evaluate(x=X_train, y=y_train)
# Out:
# ['loss', 'sparse_categorical_accuracy']
# 14/14 [==============================] - 0s
# [0.018491612747311592, 1.0]

# %%
trained_model.evaluate(x=X_val, y=y_val)
# Out:
# 4/4 [==============================] - 0s
# [0.018392274156212807, 1.0]
